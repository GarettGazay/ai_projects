# %% [markdown]
# <a href="https://colab.research.google.com/github/GarettGazay/ai_projects/blob/master/otp_minutes_lstm_eta_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import required libraries
import tensorflow as tf
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/2022_otp_runs_eta.csv')

# %%
# df = df.drop(['pickup_month', 'pickup_day', 'median_pickup_time_hour'],axis=1)

# %%
df.head()
# Out:
#    pickup_lng  pickup_lat  dropoff_lng  dropoff_lat  start_dropoff_lng  \
# 0   -0.989852    0.847646    -0.989807     0.302661          -0.989852
# 1   -0.990825    0.848788    -0.990424     0.303688          -0.990825
# 2   -0.990922    0.846670    -0.990674     0.303178          -0.990424
# 3   -0.990800    0.846893    -0.990674     0.303178          -0.990674
# 4   -0.989395    0.845235    -0.990521     0.303068          -0.989395
#
#    start_dropoff_lat  median_pickup_time_hour  median_pickup_time_minute  \
# 0           0.303341                 0.333333                   0.366667
# 1           0.303750                 0.166667                   0.383333
# 2           0.303688                 0.208333                   0.050000
# 3           0.303178                 0.208333                   0.216667
# 4           0.302478                 0.458333                   0.133333
#
#    median_dropoff_time_hour  median_dropoff_time_minute  pickup_eta_hour  \
# 0                  0.333333                    0.733333         0.333333
# 1                  0.166667                    0.800000         0.166667
# 2                  0.208333                    0.516667         0.208333
# 3                  0.208333                    0.483333         0.208333
# 4                  0.458333                    0.766667         0.458333
#
#    pickup_eta_minute  dropoff_eta_hour  dropoff_eta_minute  \
# 0           0.366667          0.333333            0.766667
# 1           0.383333          0.166667            0.816667
# 2           0.050000          0.208333            0.500000
# 3           0.216667          0.208333            0.483333
# 4           0.183333          0.458333            0.816667
#
#    start_median_dropoff_time_hour  start_median_dropoff_time_minute  \
# 0                        0.333333                          0.366667
# 1                        0.166667                          0.383333
# 2                        0.166667                          0.800000
# 3                        0.208333                          0.516667
# 4                        0.458333                          0.133333
#
#    billable_distance
# 0           0.088237
# 1           0.057734
# 2           0.029978
# 3           0.017937
# 4           0.109662

# %%
# Create train and test splits the right way for time series data
split_size = int(0.8 * len(df)) # 80% train, 20% test
split_size
# Out:
# 21879

# %%
X_minute = df

# %%
y_minute = X_minute["median_pickup_time_minute"]
X_minute = X_minute.drop(['median_pickup_time_minute'], axis=1)

# %%
# Create train data splits (everything before the split)
X_train, y_train = X_minute[:split_size], y_minute[:split_size]

# %%
y_train.head(25)
# Out:
# 0     0.366667
# 1     0.383333
# 2     0.050000
# 3     0.216667
# 4     0.133333
# 5     0.716667
# 6     0.983333
# 7     0.850000
# 8     0.966667
# 9     0.333333
# 10    0.033333
# 11    0.050000
# 12    0.933333
# 13    0.366667
# 14    0.016667
# 15    0.950000
# 16    0.933333
# 17    0.566667
# 18    0.966667
# 19    0.783333
# 20    0.616667
# 21    0.716667
# 22    0.033333
# 23    0.866667
# 24    0.316667
# Name: median_pickup_time_minute, dtype: float64

# %%
# Create test data splits (everything after the split)
X_test, y_test = X_minute[split_size:], y_minute[split_size:]

# %%
X_train = X_train.astype('float32')
y_train = y_train.astype('float32')
X_test = X_test.astype('float32')
y_test = y_test.astype('float32')

X_train.dtypes, y_train.dtypes, X_test.dtypes, y_test.dtypes
# Out:
# (pickup_lng                          float32
#  pickup_lat                          float32
#  dropoff_lng                         float32
#  dropoff_lat                         float32
#  start_dropoff_lng                   float32
#  start_dropoff_lat                   float32
#  median_pickup_time_hour             float32
#  median_dropoff_time_hour            float32
#  median_dropoff_time_minute          float32
#  pickup_eta_hour                     float32
#  pickup_eta_minute                   float32
#  dropoff_eta_hour                    float32
#  dropoff_eta_minute                  float32
#  start_median_dropoff_time_hour      float32
#  start_median_dropoff_time_minute    float32
#  billable_distance                   float32
#  dtype: object, dtype('float32'), pickup_lng                          float32
#  pickup_lat                          float32
#  dropoff_lng                         float32
#  dropoff_lat                         float32
#  start_dropoff_lng                   float32
#  start_dropoff_lat                   float32
#  median_pickup_time_hour             float32
#  median_dropoff_time_hour            float32
#  median_dropoff_time_minute          float32
#  pickup_eta_hour                     float32
#  pickup_eta_minute                   float32
#  dropoff_eta_hour                    float32
#  dropoff_eta_minute                  float32
#  start_median_dropoff_time_hour      float32
#  start_median_dropoff_time_minute    float32
#  billable_distance                   float32
#  dtype: object, dtype('float32'))

# %%
X_train.head()
# Out:
#    pickup_lng  pickup_lat  dropoff_lng  dropoff_lat  start_dropoff_lng  \
# 0   -0.989852    0.847646    -0.989807     0.302661          -0.989852
# 1   -0.990825    0.848788    -0.990424     0.303688          -0.990825
# 2   -0.990922    0.846670    -0.990674     0.303178          -0.990424
# 3   -0.990800    0.846893    -0.990674     0.303178          -0.990674
# 4   -0.989395    0.845235    -0.990521     0.303068          -0.989395
#
#    start_dropoff_lat  median_pickup_time_hour  median_dropoff_time_hour  \
# 0           0.303341                 0.333333                  0.333333
# 1           0.303750                 0.166667                  0.166667
# 2           0.303688                 0.208333                  0.208333
# 3           0.303178                 0.208333                  0.208333
# 4           0.302478                 0.458333                  0.458333
#
#    median_dropoff_time_minute  pickup_eta_hour  pickup_eta_minute  \
# 0                    0.733333         0.333333           0.366667
# 1                    0.800000         0.166667           0.383333
# 2                    0.516667         0.208333           0.050000
# 3                    0.483333         0.208333           0.216667
# 4                    0.766667         0.458333           0.183333
#
#    dropoff_eta_hour  dropoff_eta_minute  start_median_dropoff_time_hour  \
# 0          0.333333            0.766667                        0.333333
# 1          0.166667            0.816667                        0.166667
# 2          0.208333            0.500000                        0.166667
# 3          0.208333            0.483333                        0.208333
# 4          0.458333            0.816667                        0.458333
#
#    start_median_dropoff_time_minute  billable_distance
# 0                          0.366667           0.088237
# 1                          0.383333           0.057734
# 2                          0.800000           0.029978
# 3                          0.516667           0.017937
# 4                          0.133333           0.109662

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='mae', patience=5)

# %%
X_train.shape
# Out:
# (21879, 16)

# %%
X_train = X_train.values.reshape(X_train.shape[0], 1, X_train.shape[1])
# Create a new model
minute_model = tf.keras.Sequential([
  tf.keras.layers.LSTM(64, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
  tf.keras.layers.LSTM(64, return_sequences=True),
  tf.keras.layers.LSTM(32),
  tf.keras.layers.Dense(1)
])

# Compile the model
minute_model.compile(loss=tf.keras.losses.mae,
                optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
                metrics=['mae'],
                )

history = minute_model.fit(
    X_train,
    y_train,
    epochs=500,
    batch_size=32,
    validation_split=0.1,
    verbose=2,
    callbacks=[early_stopping]
    )

# X_train = X_train.values.reshape(X_train.shape[0], 1, X_train.shape[1])

# minute_model = tf.keras.Sequential()

# # Add a GRU layer with 128 units and return the full sequence of outputs
# minute_model.add(tf.keras.layers.GRU(128, return_sequences=True, input_shape=(None, 13) ))
# # Add another GRU layer with 64 units
# minute_model.add(tf.keras.layers.GRU(64))
# # Add a dense layer with 10 units and a softmax activation function
# minute_model.add(tf.keras.layers.Dense(1, activation='linear'))

# # Compile the model with a categorical crossentropy loss function and an Adam optimizer
# minute_model.compile(loss='mae', optimizer='adam')

# history = minute_model.fit(
#     X_train,
#     y_train,
#     epochs=500,
#     batch_size=32,
#     validation_split=0.1,
#     verbose=2,
#     callbacks=[early_stopping]
#     )




# Create a new model (same as model_2)
# minute_model = tf.keras.Sequential([
#   tf.keras.layers.Dense(34, activation='relu'),
#   tf.keras.layers.Dense(34, activation='relu'),
#   tf.keras.layers.Dense(16, activation='relu'),
#   tf.keras.layers.Dense(1)
# ])

# # Compile the model
# minute_model.compile(loss=tf.keras.losses.mae,
#                 optimizer=tf.keras.optimizers.Adam(),
#                 metrics=['mae'],
#                 )

# history = minute_model.fit(
#     X_train,
#     y_train,
#     epochs=500,
#     batch_size=32,
#     validation_split=0.1,
#     verbose=2,
#     callbacks=[early_stopping]
#     )


# # Create a new model
# minute_model = tf.keras.Sequential([
#   tf.keras.layers.LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
#   tf.keras.layers.LSTM(25),
#   tf.keras.layers.Dense(1)
# ])

# # Compile the model
# minute_model.compile(loss=tf.keras.losses.mae,
#                 optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
#                 metrics=['mae'],
#                 )

# history = minute_model.fit(
#     X_train,
#     y_train,
#     epochs=500,
#     batch_size=32,
#     validation_split=0.1,
#     verbose=2,
#     callbacks=[early_stopping]
#     )
# Out:
# Epoch 1/500
# 616/616 - 12s - loss: 0.2867 - mae: 0.2867 - val_loss: 0.2091 - val_mae: 0.2091 - 12s/epoch - 20ms/step
# Epoch 2/500
# 616/616 - 3s - loss: 0.1467 - mae: 0.1467 - val_loss: 0.1054 - val_mae: 0.1054 - 3s/epoch - 5ms/step
# Epoch 3/500
# 616/616 - 3s - loss: 0.0982 - mae: 0.0982 - val_loss: 0.1033 - val_mae: 0.1033 - 3s/epoch - 5ms/step
# Epoch 4/500
# 616/616 - 3s - loss: 0.0955 - mae: 0.0955 - val_loss: 0.1012 - val_mae: 0.1012 - 3s/epoch - 5ms/step
# Epoch 5/500
# 616/616 - 3s - loss: 0.0933 - mae: 0.0933 - val_loss: 0.0993 - val_mae: 0.0993 - 3s/epoch - 5ms/step
# Epoch 6/500
# 616/616 - 3s - loss: 0.0914 - mae: 0.0914 - val_loss: 0.0978 - val_mae: 0.0978 - 3s/epoch - 5ms/step
# Epoch 7/500
# 616/616 - 3s - loss: 0.0899 - mae: 0.0899 - val_loss: 0.0966 - val_mae: 0.0966 - 3s/epoch - 5ms/step
# Epoch 8/500
# 616/616 - 3s - loss: 0.0889 - mae: 0.0889 - val_loss: 0.0963 - val_mae: 0.0963 - 3s/epoch - 5ms/step
# Epoch 9/500
# 616/616 - 4s - loss: 0.0883 - mae: 0.0883 - val_loss: 0.0955 - val_mae: 0.0955 - 4s/epoch - 6ms/step
# Epoch 10/500
# 616/616 - 3s - loss: 0.0879 - mae: 0.0879 - val_loss: 0.0950 - val_mae: 0.0950 - 3s/epoch - 5ms/step
# Epoch 11/500
# 616/616 - 3s - loss: 0.0876 - mae: 0.0876 - val_loss: 0.0957 - val_mae: 0.0957 - 3s/epoch - 5ms/step
# Epoch 12/500
# 616/616 - 3s - loss: 0.0874 - mae: 0.0874 - val_loss: 0.0958 - val_mae: 0.0958 - 3s/epoch - 5ms/step
# Epoch 13/500
# 616/616 - 3s - loss: 0.0873 - mae: 0.0873 - val_loss: 0.0947 - val_mae: 0.0947 - 3s/epoch - 5ms/step
# Epoch 14/500
# 616/616 - 3s - loss: 0.0872 - mae: 0.0872 - val_loss: 0.0944 - val_mae: 0.0944 - 3s/epoch - 5ms/step
# Epoch 15/500
# 616/616 - 3s - loss: 0.0872 - mae: 0.0872 - val_loss: 0.0946 - val_mae: 0.0946 - 3s/epoch - 5ms/step
# Epoch 16/500
# 616/616 - 3s - loss: 0.0871 - mae: 0.0871 - val_loss: 0.0944 - val_mae: 0.0944 - 3s/epoch - 5ms/step
# Epoch 17/500
# 616/616 - 3s - loss: 0.0871 - mae: 0.0871 - val_loss: 0.0945 - val_mae: 0.0945 - 3s/epoch - 5ms/step
# Epoch 18/500
# 616/616 - 3s - loss: 0.0871 - mae: 0.0871 - val_loss: 0.0948 - val_mae: 0.0948 - 3s/epoch - 5ms/step
# Epoch 19/500
# 616/616 - 3s - loss: 0.0870 - mae: 0.0870 - val_loss: 0.0945 - val_mae: 0.0945 - 3s/epoch - 5ms/step
# Epoch 20/500
# 616/616 - 3s - loss: 0.0870 - mae: 0.0870 - val_loss: 0.0942 - val_mae: 0.0942 - 3s/epoch - 5ms/step
# Epoch 21/500
# 616/616 - 3s - loss: 0.0869 - mae: 0.0869 - val_loss: 0.0940 - val_mae: 0.0940 - 3s/epoch - 5ms/step
# Epoch 22/500
# 616/616 - 3s - loss: 0.0869 - mae: 0.0869 - val_loss: 0.0942 - val_mae: 0.0942 - 3s/epoch - 5ms/step
# Epoch 23/500
# 616/616 - 3s - loss: 0.0868 - mae: 0.0868 - val_loss: 0.0942 - val_mae: 0.0942 - 3s/epoch - 5ms/step
# Epoch 24/500
# 616/616 - 3s - loss: 0.0868 - mae: 0.0868 - val_loss: 0.0942 - val_mae: 0.0942 - 3s/epoch - 5ms/step
# Epoch 25/500
# 616/616 - 3s - loss: 0.0868 - mae: 0.0868 - val_loss: 0.0940 - val_mae: 0.0940 - 3s/epoch - 5ms/step
# Epoch 26/500
# 616/616 - 3s - loss: 0.0867 - mae: 0.0867 - val_loss: 0.0940 - val_mae: 0.0940 - 3s/epoch - 5ms/step
# Epoch 27/500
# 616/616 - 3s - loss: 0.0867 - mae: 0.0867 - val_loss: 0.0943 - val_mae: 0.0943 - 3s/epoch - 5ms/step
# Epoch 28/500
# 616/616 - 3s - loss: 0.0866 - mae: 0.0866 - val_loss: 0.0944 - val_mae: 0.0944 - 3s/epoch - 5ms/step
# Epoch 29/500
# 616/616 - 3s - loss: 0.0866 - mae: 0.0866 - val_loss: 0.0970 - val_mae: 0.0970 - 3s/epoch - 5ms/step
# Epoch 30/500
# 616/616 - 3s - loss: 0.0866 - mae: 0.0866 - val_loss: 0.0937 - val_mae: 0.0937 - 3s/epoch - 5ms/step
# Epoch 31/500
# 616/616 - 3s - loss: 0.0865 - mae: 0.0865 - val_loss: 0.0938 - val_mae: 0.0938 - 3s/epoch - 5ms/step
# Epoch 32/500
# 616/616 - 3s - loss: 0.0866 - mae: 0.0866 - val_loss: 0.0937 - val_mae: 0.0937 - 3s/epoch - 5ms/step
# Epoch 33/500
# 616/616 - 3s - loss: 0.0864 - mae: 0.0864 - val_loss: 0.0936 - val_mae: 0.0936 - 3s/epoch - 5ms/step
# Epoch 34/500
# 616/616 - 3s - loss: 0.0864 - mae: 0.0864 - val_loss: 0.0935 - val_mae: 0.0935 - 3s/epoch - 5ms/step
# Epoch 35/500
# 616/616 - 3s - loss: 0.0864 - mae: 0.0864 - val_loss: 0.0936 - val_mae: 0.0936 - 3s/epoch - 5ms/step
# Epoch 36/500
# 616/616 - 3s - loss: 0.0864 - mae: 0.0864 - val_loss: 0.0935 - val_mae: 0.0935 - 3s/epoch - 5ms/step
# Epoch 37/500
# 616/616 - 3s - loss: 0.0863 - mae: 0.0863 - val_loss: 0.0934 - val_mae: 0.0934 - 3s/epoch - 5ms/step
# Epoch 38/500
# 616/616 - 3s - loss: 0.0863 - mae: 0.0863 - val_loss: 0.0940 - val_mae: 0.0940 - 3s/epoch - 5ms/step
# Epoch 39/500
# 616/616 - 3s - loss: 0.0863 - mae: 0.0863 - val_loss: 0.0933 - val_mae: 0.0933 - 3s/epoch - 5ms/step
# Epoch 40/500
# 616/616 - 3s - loss: 0.0862 - mae: 0.0862 - val_loss: 0.0935 - val_mae: 0.0935 - 3s/epoch - 5ms/step
# Epoch 41/500
# 616/616 - 3s - loss: 0.0861 - mae: 0.0861 - val_loss: 0.0937 - val_mae: 0.0937 - 3s/epoch - 5ms/step
# Epoch 42/500
# 616/616 - 3s - loss: 0.0862 - mae: 0.0862 - val_loss: 0.0933 - val_mae: 0.0933 - 3s/epoch - 5ms/step
# Epoch 43/500
# 616/616 - 3s - loss: 0.0861 - mae: 0.0861 - val_loss: 0.0931 - val_mae: 0.0931 - 3s/epoch - 5ms/step
# Epoch 44/500
# 616/616 - 3s - loss: 0.0861 - mae: 0.0861 - val_loss: 0.0932 - val_mae: 0.0932 - 3s/epoch - 5ms/step
# Epoch 45/500
# 616/616 - 3s - loss: 0.0860 - mae: 0.0860 - val_loss: 0.0930 - val_mae: 0.0930 - 3s/epoch - 5ms/step
# Epoch 46/500
# 616/616 - 3s - loss: 0.0860 - mae: 0.0860 - val_loss: 0.0931 - val_mae: 0.0931 - 3s/epoch - 5ms/step
# Epoch 47/500
# 616/616 - 3s - loss: 0.0859 - mae: 0.0859 - val_loss: 0.0929 - val_mae: 0.0929 - 3s/epoch - 5ms/step
# Epoch 48/500
# 616/616 - 3s - loss: 0.0859 - mae: 0.0859 - val_loss: 0.0929 - val_mae: 0.0929 - 3s/epoch - 5ms/step
# Epoch 49/500
# 616/616 - 3s - loss: 0.0859 - mae: 0.0859 - val_loss: 0.0931 - val_mae: 0.0931 - 3s/epoch - 5ms/step
# Epoch 50/500
# 616/616 - 3s - loss: 0.0859 - mae: 0.0859 - val_loss: 0.0928 - val_mae: 0.0928 - 3s/epoch - 5ms/step
# Epoch 51/500
# 616/616 - 3s - loss: 0.0858 - mae: 0.0858 - val_loss: 0.0927 - val_mae: 0.0927 - 3s/epoch - 5ms/step
# Epoch 52/500
# 616/616 - 3s - loss: 0.0856 - mae: 0.0856 - val_loss: 0.0927 - val_mae: 0.0927 - 3s/epoch - 5ms/step
# Epoch 53/500
# 616/616 - 3s - loss: 0.0857 - mae: 0.0857 - val_loss: 0.0926 - val_mae: 0.0926 - 3s/epoch - 5ms/step
# Epoch 54/500
# 616/616 - 3s - loss: 0.0856 - mae: 0.0856 - val_loss: 0.0926 - val_mae: 0.0926 - 3s/epoch - 5ms/step
# Epoch 55/500
# 616/616 - 3s - loss: 0.0857 - mae: 0.0857 - val_loss: 0.0933 - val_mae: 0.0933 - 3s/epoch - 5ms/step
# Epoch 56/500
# 616/616 - 3s - loss: 0.0856 - mae: 0.0856 - val_loss: 0.0925 - val_mae: 0.0925 - 3s/epoch - 5ms/step
# Epoch 57/500
# 616/616 - 3s - loss: 0.0855 - mae: 0.0855 - val_loss: 0.0925 - val_mae: 0.0925 - 3s/epoch - 6ms/step
# Epoch 58/500
# 616/616 - 3s - loss: 0.0855 - mae: 0.0855 - val_loss: 0.0925 - val_mae: 0.0925 - 3s/epoch - 5ms/step
# Epoch 59/500
# 616/616 - 3s - loss: 0.0854 - mae: 0.0854 - val_loss: 0.0923 - val_mae: 0.0923 - 3s/epoch - 5ms/step
# Epoch 60/500
# 616/616 - 3s - loss: 0.0854 - mae: 0.0854 - val_loss: 0.0933 - val_mae: 0.0933 - 3s/epoch - 5ms/step
# Epoch 61/500
# 616/616 - 3s - loss: 0.0853 - mae: 0.0853 - val_loss: 0.0922 - val_mae: 0.0922 - 3s/epoch - 5ms/step
# Epoch 62/500
# 616/616 - 3s - loss: 0.0853 - mae: 0.0853 - val_loss: 0.0925 - val_mae: 0.0925 - 3s/epoch - 5ms/step
# Epoch 63/500
# 616/616 - 3s - loss: 0.0852 - mae: 0.0852 - val_loss: 0.0922 - val_mae: 0.0922 - 3s/epoch - 5ms/step
# Epoch 64/500
# 616/616 - 3s - loss: 0.0851 - mae: 0.0851 - val_loss: 0.0920 - val_mae: 0.0920 - 3s/epoch - 5ms/step
# Epoch 65/500
# 616/616 - 3s - loss: 0.0851 - mae: 0.0851 - val_loss: 0.0925 - val_mae: 0.0925 - 3s/epoch - 5ms/step
# Epoch 66/500
# 616/616 - 3s - loss: 0.0851 - mae: 0.0851 - val_loss: 0.0921 - val_mae: 0.0921 - 3s/epoch - 5ms/step
# Epoch 67/500
# 616/616 - 3s - loss: 0.0850 - mae: 0.0850 - val_loss: 0.0918 - val_mae: 0.0918 - 3s/epoch - 5ms/step
# Epoch 68/500
# 616/616 - 3s - loss: 0.0850 - mae: 0.0850 - val_loss: 0.0921 - val_mae: 0.0921 - 3s/epoch - 5ms/step
# Epoch 69/500
# 616/616 - 3s - loss: 0.0848 - mae: 0.0848 - val_loss: 0.0935 - val_mae: 0.0935 - 3s/epoch - 5ms/step
# Epoch 70/500
# 616/616 - 3s - loss: 0.0849 - mae: 0.0849 - val_loss: 0.0928 - val_mae: 0.0928 - 3s/epoch - 5ms/step
# Epoch 71/500
# 616/616 - 3s - loss: 0.0847 - mae: 0.0847 - val_loss: 0.0922 - val_mae: 0.0922 - 3s/epoch - 5ms/step
# Epoch 72/500
# 616/616 - 3s - loss: 0.0846 - mae: 0.0846 - val_loss: 0.0913 - val_mae: 0.0913 - 3s/epoch - 5ms/step
# Epoch 73/500
# 616/616 - 3s - loss: 0.0846 - mae: 0.0846 - val_loss: 0.0923 - val_mae: 0.0923 - 3s/epoch - 5ms/step
# Epoch 74/500
# 616/616 - 3s - loss: 0.0847 - mae: 0.0847 - val_loss: 0.0912 - val_mae: 0.0912 - 3s/epoch - 5ms/step
# Epoch 75/500
# 616/616 - 3s - loss: 0.0845 - mae: 0.0845 - val_loss: 0.0916 - val_mae: 0.0916 - 3s/epoch - 5ms/step
# Epoch 76/500
# 616/616 - 3s - loss: 0.0844 - mae: 0.0844 - val_loss: 0.0911 - val_mae: 0.0911 - 3s/epoch - 5ms/step
# Epoch 77/500
# 616/616 - 3s - loss: 0.0844 - mae: 0.0844 - val_loss: 0.0913 - val_mae: 0.0913 - 3s/epoch - 5ms/step
# Epoch 78/500
# 616/616 - 3s - loss: 0.0842 - mae: 0.0842 - val_loss: 0.0915 - val_mae: 0.0915 - 3s/epoch - 5ms/step
# Epoch 79/500
# 616/616 - 3s - loss: 0.0843 - mae: 0.0843 - val_loss: 0.0912 - val_mae: 0.0912 - 3s/epoch - 5ms/step
# Epoch 80/500
# 616/616 - 3s - loss: 0.0841 - mae: 0.0841 - val_loss: 0.0908 - val_mae: 0.0908 - 3s/epoch - 5ms/step
# Epoch 81/500
# 616/616 - 3s - loss: 0.0841 - mae: 0.0841 - val_loss: 0.0906 - val_mae: 0.0906 - 3s/epoch - 5ms/step
# Epoch 82/500
# 616/616 - 3s - loss: 0.0839 - mae: 0.0839 - val_loss: 0.0914 - val_mae: 0.0914 - 3s/epoch - 5ms/step
# Epoch 83/500
# 616/616 - 3s - loss: 0.0839 - mae: 0.0839 - val_loss: 0.0907 - val_mae: 0.0907 - 3s/epoch - 5ms/step
# Epoch 84/500
# 616/616 - 3s - loss: 0.0837 - mae: 0.0837 - val_loss: 0.0910 - val_mae: 0.0910 - 3s/epoch - 5ms/step
# Epoch 85/500
# 616/616 - 3s - loss: 0.0836 - mae: 0.0836 - val_loss: 0.0907 - val_mae: 0.0907 - 3s/epoch - 5ms/step
# Epoch 86/500
# 616/616 - 3s - loss: 0.0836 - mae: 0.0836 - val_loss: 0.0901 - val_mae: 0.0901 - 3s/epoch - 5ms/step
# Epoch 87/500
# 616/616 - 3s - loss: 0.0835 - mae: 0.0835 - val_loss: 0.0899 - val_mae: 0.0899 - 3s/epoch - 5ms/step
# Epoch 88/500
# 616/616 - 3s - loss: 0.0834 - mae: 0.0834 - val_loss: 0.0903 - val_mae: 0.0903 - 3s/epoch - 5ms/step
# Epoch 89/500
# 616/616 - 3s - loss: 0.0834 - mae: 0.0834 - val_loss: 0.0901 - val_mae: 0.0901 - 3s/epoch - 5ms/step
# Epoch 90/500
# 616/616 - 3s - loss: 0.0832 - mae: 0.0832 - val_loss: 0.0898 - val_mae: 0.0898 - 3s/epoch - 5ms/step
# Epoch 91/500
# 616/616 - 3s - loss: 0.0832 - mae: 0.0832 - val_loss: 0.0925 - val_mae: 0.0925 - 3s/epoch - 5ms/step
# Epoch 92/500
# 616/616 - 3s - loss: 0.0830 - mae: 0.0830 - val_loss: 0.0895 - val_mae: 0.0895 - 3s/epoch - 5ms/step
# Epoch 93/500
# 616/616 - 3s - loss: 0.0829 - mae: 0.0829 - val_loss: 0.0893 - val_mae: 0.0893 - 3s/epoch - 5ms/step
# Epoch 94/500
# 616/616 - 3s - loss: 0.0828 - mae: 0.0828 - val_loss: 0.0908 - val_mae: 0.0908 - 3s/epoch - 5ms/step
# Epoch 95/500
# 616/616 - 3s - loss: 0.0827 - mae: 0.0827 - val_loss: 0.0890 - val_mae: 0.0890 - 3s/epoch - 5ms/step
# Epoch 96/500
# 616/616 - 3s - loss: 0.0825 - mae: 0.0825 - val_loss: 0.0891 - val_mae: 0.0891 - 3s/epoch - 5ms/step
# Epoch 97/500
# 616/616 - 3s - loss: 0.0825 - mae: 0.0825 - val_loss: 0.0888 - val_mae: 0.0888 - 3s/epoch - 5ms/step
# Epoch 98/500
# 616/616 - 3s - loss: 0.0822 - mae: 0.0822 - val_loss: 0.0884 - val_mae: 0.0884 - 3s/epoch - 5ms/step
# Epoch 99/500
# 616/616 - 3s - loss: 0.0821 - mae: 0.0821 - val_loss: 0.0880 - val_mae: 0.0880 - 3s/epoch - 5ms/step
# Epoch 100/500
# 616/616 - 3s - loss: 0.0820 - mae: 0.0820 - val_loss: 0.0883 - val_mae: 0.0883 - 3s/epoch - 5ms/step
# Epoch 101/500
# 616/616 - 3s - loss: 0.0820 - mae: 0.0820 - val_loss: 0.0877 - val_mae: 0.0877 - 3s/epoch - 5ms/step
# Epoch 102/500
# 616/616 - 3s - loss: 0.0816 - mae: 0.0816 - val_loss: 0.0876 - val_mae: 0.0876 - 3s/epoch - 5ms/step
# Epoch 103/500
# 616/616 - 3s - loss: 0.0816 - mae: 0.0816 - val_loss: 0.0873 - val_mae: 0.0873 - 3s/epoch - 5ms/step
# Epoch 104/500
# 616/616 - 3s - loss: 0.0814 - mae: 0.0814 - val_loss: 0.0871 - val_mae: 0.0871 - 3s/epoch - 5ms/step
# Epoch 105/500
# 616/616 - 3s - loss: 0.0812 - mae: 0.0812 - val_loss: 0.0873 - val_mae: 0.0873 - 3s/epoch - 5ms/step
# Epoch 106/500
# 616/616 - 4s - loss: 0.0811 - mae: 0.0811 - val_loss: 0.0868 - val_mae: 0.0868 - 4s/epoch - 6ms/step
# Epoch 107/500
# 616/616 - 3s - loss: 0.0808 - mae: 0.0808 - val_loss: 0.0865 - val_mae: 0.0865 - 3s/epoch - 5ms/step
# Epoch 108/500
# 616/616 - 3s - loss: 0.0807 - mae: 0.0807 - val_loss: 0.0866 - val_mae: 0.0866 - 3s/epoch - 5ms/step
# Epoch 109/500
# 616/616 - 3s - loss: 0.0804 - mae: 0.0804 - val_loss: 0.0862 - val_mae: 0.0862 - 3s/epoch - 5ms/step
# Epoch 110/500
# 616/616 - 3s - loss: 0.0802 - mae: 0.0802 - val_loss: 0.0863 - val_mae: 0.0863 - 3s/epoch - 5ms/step
# Epoch 111/500
# 616/616 - 3s - loss: 0.0801 - mae: 0.0801 - val_loss: 0.0875 - val_mae: 0.0875 - 3s/epoch - 5ms/step
# Epoch 112/500
# 616/616 - 3s - loss: 0.0797 - mae: 0.0797 - val_loss: 0.0864 - val_mae: 0.0864 - 3s/epoch - 5ms/step
# Epoch 113/500
# 616/616 - 3s - loss: 0.0797 - mae: 0.0797 - val_loss: 0.0848 - val_mae: 0.0848 - 3s/epoch - 5ms/step
# Epoch 114/500
# 616/616 - 3s - loss: 0.0794 - mae: 0.0794 - val_loss: 0.0850 - val_mae: 0.0850 - 3s/epoch - 5ms/step
# Epoch 115/500
# 616/616 - 3s - loss: 0.0790 - mae: 0.0790 - val_loss: 0.0847 - val_mae: 0.0847 - 3s/epoch - 5ms/step
# Epoch 116/500
# 616/616 - 3s - loss: 0.0788 - mae: 0.0788 - val_loss: 0.0837 - val_mae: 0.0837 - 3s/epoch - 5ms/step
# Epoch 117/500
# 616/616 - 3s - loss: 0.0786 - mae: 0.0786 - val_loss: 0.0837 - val_mae: 0.0837 - 3s/epoch - 5ms/step
# Epoch 118/500
# 616/616 - 3s - loss: 0.0782 - mae: 0.0782 - val_loss: 0.0828 - val_mae: 0.0828 - 3s/epoch - 5ms/step
# Epoch 119/500
# 616/616 - 3s - loss: 0.0779 - mae: 0.0779 - val_loss: 0.0829 - val_mae: 0.0829 - 3s/epoch - 5ms/step
# Epoch 120/500
# 616/616 - 3s - loss: 0.0776 - mae: 0.0776 - val_loss: 0.0822 - val_mae: 0.0822 - 3s/epoch - 5ms/step
# Epoch 121/500
# 616/616 - 3s - loss: 0.0775 - mae: 0.0775 - val_loss: 0.0819 - val_mae: 0.0819 - 3s/epoch - 5ms/step
# Epoch 122/500
# 616/616 - 3s - loss: 0.0769 - mae: 0.0769 - val_loss: 0.0811 - val_mae: 0.0811 - 3s/epoch - 5ms/step
# Epoch 123/500
# 616/616 - 3s - loss: 0.0764 - mae: 0.0764 - val_loss: 0.0806 - val_mae: 0.0806 - 3s/epoch - 5ms/step
# Epoch 124/500
# 616/616 - 3s - loss: 0.0760 - mae: 0.0760 - val_loss: 0.0808 - val_mae: 0.0808 - 3s/epoch - 5ms/step
# Epoch 125/500
# 616/616 - 3s - loss: 0.0759 - mae: 0.0759 - val_loss: 0.0800 - val_mae: 0.0800 - 3s/epoch - 5ms/step
# Epoch 126/500
# 616/616 - 3s - loss: 0.0757 - mae: 0.0757 - val_loss: 0.0813 - val_mae: 0.0813 - 3s/epoch - 5ms/step
# Epoch 127/500
# 616/616 - 3s - loss: 0.0757 - mae: 0.0757 - val_loss: 0.0803 - val_mae: 0.0803 - 3s/epoch - 5ms/step
# Epoch 128/500
# 616/616 - 3s - loss: 0.0754 - mae: 0.0754 - val_loss: 0.0796 - val_mae: 0.0796 - 3s/epoch - 5ms/step
# Epoch 129/500
# 616/616 - 3s - loss: 0.0755 - mae: 0.0755 - val_loss: 0.0799 - val_mae: 0.0799 - 3s/epoch - 5ms/step
# Epoch 130/500
# 616/616 - 3s - loss: 0.0755 - mae: 0.0755 - val_loss: 0.0800 - val_mae: 0.0800 - 3s/epoch - 5ms/step
# Epoch 131/500
# 616/616 - 3s - loss: 0.0751 - mae: 0.0751 - val_loss: 0.0803 - val_mae: 0.0803 - 3s/epoch - 5ms/step
# Epoch 132/500
# 616/616 - 3s - loss: 0.0752 - mae: 0.0752 - val_loss: 0.0808 - val_mae: 0.0808 - 3s/epoch - 5ms/step
# Epoch 133/500
# 616/616 - 3s - loss: 0.0749 - mae: 0.0749 - val_loss: 0.0806 - val_mae: 0.0806 - 3s/epoch - 5ms/step
# Epoch 134/500
# 616/616 - 3s - loss: 0.0750 - mae: 0.0750 - val_loss: 0.0793 - val_mae: 0.0793 - 3s/epoch - 5ms/step
# Epoch 135/500
# 616/616 - 3s - loss: 0.0748 - mae: 0.0748 - val_loss: 0.0809 - val_mae: 0.0809 - 3s/epoch - 5ms/step
# Epoch 136/500
# 616/616 - 3s - loss: 0.0747 - mae: 0.0747 - val_loss: 0.0798 - val_mae: 0.0798 - 3s/epoch - 5ms/step
# Epoch 137/500
# 616/616 - 3s - loss: 0.0747 - mae: 0.0747 - val_loss: 0.0790 - val_mae: 0.0790 - 3s/epoch - 5ms/step
# Epoch 138/500
# 616/616 - 3s - loss: 0.0745 - mae: 0.0745 - val_loss: 0.0812 - val_mae: 0.0812 - 3s/epoch - 5ms/step
# Epoch 139/500
# 616/616 - 3s - loss: 0.0743 - mae: 0.0743 - val_loss: 0.0811 - val_mae: 0.0811 - 3s/epoch - 5ms/step
# Epoch 140/500
# 616/616 - 3s - loss: 0.0743 - mae: 0.0743 - val_loss: 0.0801 - val_mae: 0.0801 - 3s/epoch - 5ms/step
# Epoch 141/500
# 616/616 - 3s - loss: 0.0743 - mae: 0.0743 - val_loss: 0.0814 - val_mae: 0.0814 - 3s/epoch - 5ms/step
# Epoch 142/500
# 616/616 - 3s - loss: 0.0742 - mae: 0.0742 - val_loss: 0.0862 - val_mae: 0.0862 - 3s/epoch - 5ms/step
# Epoch 143/500
# 616/616 - 3s - loss: 0.0743 - mae: 0.0743 - val_loss: 0.0783 - val_mae: 0.0783 - 3s/epoch - 5ms/step
# Epoch 144/500
# 616/616 - 3s - loss: 0.0737 - mae: 0.0737 - val_loss: 0.0780 - val_mae: 0.0780 - 3s/epoch - 5ms/step
# Epoch 145/500
# 616/616 - 3s - loss: 0.0737 - mae: 0.0737 - val_loss: 0.0778 - val_mae: 0.0778 - 3s/epoch - 5ms/step
# Epoch 146/500
# 616/616 - 3s - loss: 0.0734 - mae: 0.0734 - val_loss: 0.0781 - val_mae: 0.0781 - 3s/epoch - 5ms/step
# Epoch 147/500
# 616/616 - 3s - loss: 0.0738 - mae: 0.0738 - val_loss: 0.0798 - val_mae: 0.0798 - 3s/epoch - 5ms/step
# Epoch 148/500
# 616/616 - 3s - loss: 0.0733 - mae: 0.0733 - val_loss: 0.0775 - val_mae: 0.0775 - 3s/epoch - 5ms/step
# Epoch 149/500
# 616/616 - 3s - loss: 0.0734 - mae: 0.0734 - val_loss: 0.0777 - val_mae: 0.0777 - 3s/epoch - 5ms/step
# Epoch 150/500
# 616/616 - 3s - loss: 0.0731 - mae: 0.0731 - val_loss: 0.0777 - val_mae: 0.0777 - 3s/epoch - 5ms/step
# Epoch 151/500
# 616/616 - 3s - loss: 0.0729 - mae: 0.0729 - val_loss: 0.0771 - val_mae: 0.0771 - 3s/epoch - 5ms/step
# Epoch 152/500
# 616/616 - 3s - loss: 0.0729 - mae: 0.0729 - val_loss: 0.0792 - val_mae: 0.0792 - 3s/epoch - 5ms/step
# Epoch 153/500
# 616/616 - 4s - loss: 0.0727 - mae: 0.0727 - val_loss: 0.0770 - val_mae: 0.0770 - 4s/epoch - 6ms/step
# Epoch 154/500
# 616/616 - 3s - loss: 0.0725 - mae: 0.0725 - val_loss: 0.0772 - val_mae: 0.0772 - 3s/epoch - 5ms/step
# Epoch 155/500
# 616/616 - 3s - loss: 0.0724 - mae: 0.0724 - val_loss: 0.0766 - val_mae: 0.0766 - 3s/epoch - 5ms/step
# Epoch 156/500
# 616/616 - 3s - loss: 0.0721 - mae: 0.0721 - val_loss: 0.0825 - val_mae: 0.0825 - 3s/epoch - 5ms/step
# Epoch 157/500
# 616/616 - 3s - loss: 0.0718 - mae: 0.0718 - val_loss: 0.0760 - val_mae: 0.0760 - 3s/epoch - 5ms/step
# Epoch 158/500
# 616/616 - 3s - loss: 0.0717 - mae: 0.0717 - val_loss: 0.0761 - val_mae: 0.0761 - 3s/epoch - 5ms/step
# Epoch 159/500
# 616/616 - 3s - loss: 0.0718 - mae: 0.0718 - val_loss: 0.0760 - val_mae: 0.0760 - 3s/epoch - 5ms/step
# Epoch 160/500
# 616/616 - 3s - loss: 0.0714 - mae: 0.0714 - val_loss: 0.0767 - val_mae: 0.0767 - 3s/epoch - 5ms/step
# Epoch 161/500
# 616/616 - 3s - loss: 0.0713 - mae: 0.0713 - val_loss: 0.0755 - val_mae: 0.0755 - 3s/epoch - 5ms/step
# Epoch 162/500
# 616/616 - 3s - loss: 0.0709 - mae: 0.0709 - val_loss: 0.0759 - val_mae: 0.0759 - 3s/epoch - 5ms/step
# Epoch 163/500
# 616/616 - 3s - loss: 0.0711 - mae: 0.0711 - val_loss: 0.0749 - val_mae: 0.0749 - 3s/epoch - 5ms/step
# Epoch 164/500
# 616/616 - 3s - loss: 0.0710 - mae: 0.0710 - val_loss: 0.0753 - val_mae: 0.0753 - 3s/epoch - 5ms/step
# Epoch 165/500
# 616/616 - 3s - loss: 0.0707 - mae: 0.0707 - val_loss: 0.0750 - val_mae: 0.0750 - 3s/epoch - 5ms/step
# Epoch 166/500
# 616/616 - 3s - loss: 0.0704 - mae: 0.0704 - val_loss: 0.0751 - val_mae: 0.0751 - 3s/epoch - 5ms/step
# Epoch 167/500
# 616/616 - 3s - loss: 0.0701 - mae: 0.0701 - val_loss: 0.0746 - val_mae: 0.0746 - 3s/epoch - 5ms/step
# Epoch 168/500
# 616/616 - 3s - loss: 0.0698 - mae: 0.0698 - val_loss: 0.0766 - val_mae: 0.0766 - 3s/epoch - 5ms/step
# Epoch 169/500
# 616/616 - 3s - loss: 0.0697 - mae: 0.0697 - val_loss: 0.0752 - val_mae: 0.0752 - 3s/epoch - 5ms/step
# Epoch 170/500
# 616/616 - 3s - loss: 0.0691 - mae: 0.0691 - val_loss: 0.0734 - val_mae: 0.0734 - 3s/epoch - 5ms/step
# Epoch 171/500
# 616/616 - 3s - loss: 0.0693 - mae: 0.0693 - val_loss: 0.0814 - val_mae: 0.0814 - 3s/epoch - 5ms/step
# Epoch 172/500
# 616/616 - 3s - loss: 0.0689 - mae: 0.0689 - val_loss: 0.0727 - val_mae: 0.0727 - 3s/epoch - 5ms/step
# Epoch 173/500
# 616/616 - 3s - loss: 0.0690 - mae: 0.0690 - val_loss: 0.0724 - val_mae: 0.0724 - 3s/epoch - 5ms/step
# Epoch 174/500
# 616/616 - 3s - loss: 0.0685 - mae: 0.0685 - val_loss: 0.0726 - val_mae: 0.0726 - 3s/epoch - 5ms/step
# Epoch 175/500
# 616/616 - 3s - loss: 0.0682 - mae: 0.0682 - val_loss: 0.0743 - val_mae: 0.0743 - 3s/epoch - 5ms/step
# Epoch 176/500
# 616/616 - 3s - loss: 0.0679 - mae: 0.0679 - val_loss: 0.0828 - val_mae: 0.0828 - 3s/epoch - 5ms/step
# Epoch 177/500
# 616/616 - 3s - loss: 0.0676 - mae: 0.0676 - val_loss: 0.0717 - val_mae: 0.0717 - 3s/epoch - 5ms/step
# Epoch 178/500
# 616/616 - 3s - loss: 0.0673 - mae: 0.0673 - val_loss: 0.0711 - val_mae: 0.0711 - 3s/epoch - 5ms/step
# Epoch 179/500
# 616/616 - 3s - loss: 0.0672 - mae: 0.0672 - val_loss: 0.0715 - val_mae: 0.0715 - 3s/epoch - 5ms/step
# Epoch 180/500
# 616/616 - 3s - loss: 0.0667 - mae: 0.0667 - val_loss: 0.0715 - val_mae: 0.0715 - 3s/epoch - 5ms/step
# Epoch 181/500
# 616/616 - 3s - loss: 0.0663 - mae: 0.0663 - val_loss: 0.0715 - val_mae: 0.0715 - 3s/epoch - 5ms/step
# Epoch 182/500
# 616/616 - 3s - loss: 0.0662 - mae: 0.0662 - val_loss: 0.0701 - val_mae: 0.0701 - 3s/epoch - 5ms/step
# Epoch 183/500
# 616/616 - 3s - loss: 0.0662 - mae: 0.0662 - val_loss: 0.0703 - val_mae: 0.0703 - 3s/epoch - 5ms/step
# Epoch 184/500
# 616/616 - 3s - loss: 0.0658 - mae: 0.0658 - val_loss: 0.0698 - val_mae: 0.0698 - 3s/epoch - 5ms/step
# Epoch 185/500
# 616/616 - 3s - loss: 0.0656 - mae: 0.0656 - val_loss: 0.0716 - val_mae: 0.0716 - 3s/epoch - 5ms/step
# Epoch 186/500
# 616/616 - 3s - loss: 0.0654 - mae: 0.0654 - val_loss: 0.0693 - val_mae: 0.0693 - 3s/epoch - 5ms/step
# Epoch 187/500
# 616/616 - 3s - loss: 0.0657 - mae: 0.0657 - val_loss: 0.0691 - val_mae: 0.0691 - 3s/epoch - 5ms/step
# Epoch 188/500
# 616/616 - 3s - loss: 0.0649 - mae: 0.0649 - val_loss: 0.0684 - val_mae: 0.0684 - 3s/epoch - 5ms/step
# Epoch 189/500
# 616/616 - 3s - loss: 0.0650 - mae: 0.0650 - val_loss: 0.0682 - val_mae: 0.0682 - 3s/epoch - 5ms/step
# Epoch 190/500
# 616/616 - 3s - loss: 0.0645 - mae: 0.0645 - val_loss: 0.0692 - val_mae: 0.0692 - 3s/epoch - 5ms/step
# Epoch 191/500
# 616/616 - 3s - loss: 0.0642 - mae: 0.0642 - val_loss: 0.0677 - val_mae: 0.0677 - 3s/epoch - 5ms/step
# Epoch 192/500
# 616/616 - 3s - loss: 0.0637 - mae: 0.0637 - val_loss: 0.0721 - val_mae: 0.0721 - 3s/epoch - 5ms/step
# Epoch 193/500
# 616/616 - 3s - loss: 0.0639 - mae: 0.0639 - val_loss: 0.0709 - val_mae: 0.0709 - 3s/epoch - 5ms/step
# Epoch 194/500
# 616/616 - 3s - loss: 0.0639 - mae: 0.0639 - val_loss: 0.0677 - val_mae: 0.0677 - 3s/epoch - 5ms/step
# Epoch 195/500
# 616/616 - 3s - loss: 0.0644 - mae: 0.0644 - val_loss: 0.0704 - val_mae: 0.0704 - 3s/epoch - 5ms/step
# Epoch 196/500
# 616/616 - 3s - loss: 0.0639 - mae: 0.0639 - val_loss: 0.0712 - val_mae: 0.0712 - 3s/epoch - 5ms/step
# Epoch 197/500
# 616/616 - 3s - loss: 0.0632 - mae: 0.0632 - val_loss: 0.0673 - val_mae: 0.0673 - 3s/epoch - 5ms/step
# Epoch 198/500
# 616/616 - 3s - loss: 0.0634 - mae: 0.0634 - val_loss: 0.0692 - val_mae: 0.0692 - 3s/epoch - 5ms/step
# Epoch 199/500
# 616/616 - 3s - loss: 0.0629 - mae: 0.0629 - val_loss: 0.0704 - val_mae: 0.0704 - 3s/epoch - 5ms/step
# Epoch 200/500
# 616/616 - 4s - loss: 0.0631 - mae: 0.0631 - val_loss: 0.0738 - val_mae: 0.0738 - 4s/epoch - 6ms/step
# Epoch 201/500
# 616/616 - 3s - loss: 0.0628 - mae: 0.0628 - val_loss: 0.0666 - val_mae: 0.0666 - 3s/epoch - 5ms/step
# Epoch 202/500
# 616/616 - 3s - loss: 0.0631 - mae: 0.0631 - val_loss: 0.0665 - val_mae: 0.0665 - 3s/epoch - 5ms/step
# Epoch 203/500
# 616/616 - 3s - loss: 0.0629 - mae: 0.0629 - val_loss: 0.0667 - val_mae: 0.0667 - 3s/epoch - 5ms/step
# Epoch 204/500
# 616/616 - 3s - loss: 0.0628 - mae: 0.0628 - val_loss: 0.0684 - val_mae: 0.0684 - 3s/epoch - 5ms/step
# Epoch 205/500
# 616/616 - 3s - loss: 0.0624 - mae: 0.0624 - val_loss: 0.0888 - val_mae: 0.0888 - 3s/epoch - 5ms/step
# Epoch 206/500
# 616/616 - 3s - loss: 0.0624 - mae: 0.0624 - val_loss: 0.0669 - val_mae: 0.0669 - 3s/epoch - 5ms/step
# Epoch 207/500
# 616/616 - 3s - loss: 0.0625 - mae: 0.0625 - val_loss: 0.0666 - val_mae: 0.0666 - 3s/epoch - 5ms/step
# Epoch 208/500
# 616/616 - 3s - loss: 0.0621 - mae: 0.0621 - val_loss: 0.0690 - val_mae: 0.0690 - 3s/epoch - 5ms/step
# Epoch 209/500
# 616/616 - 3s - loss: 0.0626 - mae: 0.0626 - val_loss: 0.0684 - val_mae: 0.0684 - 3s/epoch - 5ms/step
# Epoch 210/500
# 616/616 - 3s - loss: 0.0625 - mae: 0.0625 - val_loss: 0.0690 - val_mae: 0.0690 - 3s/epoch - 5ms/step
# Epoch 211/500
# 616/616 - 3s - loss: 0.0625 - mae: 0.0625 - val_loss: 0.0673 - val_mae: 0.0673 - 3s/epoch - 5ms/step
# Epoch 212/500
# 616/616 - 3s - loss: 0.0629 - mae: 0.0629 - val_loss: 0.0685 - val_mae: 0.0685 - 3s/epoch - 5ms/step
# Epoch 213/500
# 616/616 - 3s - loss: 0.0618 - mae: 0.0618 - val_loss: 0.0660 - val_mae: 0.0660 - 3s/epoch - 5ms/step
# Epoch 214/500
# 616/616 - 3s - loss: 0.0622 - mae: 0.0622 - val_loss: 0.0665 - val_mae: 0.0665 - 3s/epoch - 5ms/step
# Epoch 215/500
# 616/616 - 3s - loss: 0.0617 - mae: 0.0617 - val_loss: 0.0659 - val_mae: 0.0659 - 3s/epoch - 5ms/step
# Epoch 216/500
# 616/616 - 3s - loss: 0.0617 - mae: 0.0617 - val_loss: 0.0669 - val_mae: 0.0669 - 3s/epoch - 5ms/step
# Epoch 217/500
# 616/616 - 3s - loss: 0.0617 - mae: 0.0617 - val_loss: 0.0700 - val_mae: 0.0700 - 3s/epoch - 5ms/step
# Epoch 218/500
# 616/616 - 3s - loss: 0.0622 - mae: 0.0622 - val_loss: 0.0726 - val_mae: 0.0726 - 3s/epoch - 5ms/step
# Epoch 219/500
# 616/616 - 3s - loss: 0.0616 - mae: 0.0616 - val_loss: 0.0684 - val_mae: 0.0684 - 3s/epoch - 5ms/step
# Epoch 220/500
# 616/616 - 3s - loss: 0.0616 - mae: 0.0616 - val_loss: 0.0671 - val_mae: 0.0671 - 3s/epoch - 5ms/step
# Epoch 221/500
# 616/616 - 3s - loss: 0.0616 - mae: 0.0616 - val_loss: 0.0660 - val_mae: 0.0660 - 3s/epoch - 5ms/step
# Epoch 222/500
# 616/616 - 3s - loss: 0.0617 - mae: 0.0617 - val_loss: 0.0670 - val_mae: 0.0670 - 3s/epoch - 5ms/step
# Epoch 223/500
# 616/616 - 3s - loss: 0.0612 - mae: 0.0612 - val_loss: 0.0659 - val_mae: 0.0659 - 3s/epoch - 5ms/step
# Epoch 224/500
# 616/616 - 3s - loss: 0.0609 - mae: 0.0609 - val_loss: 0.0701 - val_mae: 0.0701 - 3s/epoch - 5ms/step
# Epoch 225/500
# 616/616 - 3s - loss: 0.0610 - mae: 0.0610 - val_loss: 0.0659 - val_mae: 0.0659 - 3s/epoch - 5ms/step
# Epoch 226/500
# 616/616 - 3s - loss: 0.0619 - mae: 0.0619 - val_loss: 0.0675 - val_mae: 0.0675 - 3s/epoch - 5ms/step
# Epoch 227/500
# 616/616 - 3s - loss: 0.0610 - mae: 0.0610 - val_loss: 0.0761 - val_mae: 0.0761 - 3s/epoch - 5ms/step
# Epoch 228/500
# 616/616 - 3s - loss: 0.0617 - mae: 0.0617 - val_loss: 0.0683 - val_mae: 0.0683 - 3s/epoch - 5ms/step
# Epoch 229/500
# 616/616 - 3s - loss: 0.0611 - mae: 0.0611 - val_loss: 0.0717 - val_mae: 0.0717 - 3s/epoch - 5ms/step

# %%
minute_model.save('/content/drive/MyDrive/Colab_Models/otp_predict/otp_minutes_lstm_eta_0_0650')
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.

# %%
# Plot history (also known as a loss curve)
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs");

# %%
y_pred = minute_model.predict(X_test.values.reshape(X_test.shape[0], 1, X_test.shape[1]))
# Out:
# 171/171 [==============================] - 1s 3ms/step

# %%
y_pred[:10]
# Out:
# array([0.27, 0.77, 0.56, 0.89, 0.57, 0.68, 0.61, 0.77, 0.43, 0.71],
#       dtype=float32)

# %%
np.set_printoptions(precision=2)
compare = np.concatenate((y_pred.reshape(len(y_pred),1), y_test.values.reshape(len(y_test),1)),1)

for i in compare[5000:5050]:
  print(i)
# Out:
# [0.8  0.82]
# [0.16 0.15]
# [0.97 0.82]
# [0.62 0.58]
# [0.94 0.95]
# [0.82 0.78]
# [0.44 0.43]
# [0.79 0.75]
# [0.59 0.47]
# [0.21 0.13]
# [0.59 0.58]
# [0.89 0.83]
# [0.76 0.77]
# [0.08 0.08]
# [1.01 0.77]
# [0.58 0.58]
# [0.7 0. ]
# [0.96 0.95]
# [0.66 0.67]
# [0.4 0.4]
# [0.39 0.3 ]
# [0.93 0.25]
# [0.78 0.77]
# [0.63 0.6 ]
# [0.23 0.22]
# [0.81 0.75]
# [0.53 0.5 ]
# [0.67 0.65]
# [0.77 0.82]
# [0.78 0.88]
# [0.41 0.13]
# [0.05 0.05]
# [0.88 0.87]
# [0.56 0.55]
# [0.15 0.1 ]
# [0.2  0.18]
# [0.62 0.62]
# [0.23 0.23]
# [0.59 0.98]
# [0.19 0.12]
# [0.86 0.85]
# [1.39 0.15]
# [0.64 0.63]
# [0.42 0.42]
# [0.93 0.92]
# [0.35 0.12]
# [0.57 0.57]
# [0.25 0.25]
# [0.79 0.78]
# [0.55 0.52]

# %%
  plt.figure(figsize=(20, 10))

  # Plot test data in green
  plt.scatter(y_test[:5470], y_test[:5470], c="g", label="Testing data")

  # Plot the predictions in red (predictions were made on the test data)
  plt.scatter(y_test[:5470], y_pred[:5470], c="r", s=4, label="Predictions")
  # Show the legend
  plt.legend();

# %%
y_test.shape
# Out:
# (5470,)

# %%
y_pred_heat = np.array(tf.squeeze(y_pred))
y_pred_heat.shape, y_test.shape

y_pred_heat[:10]
y_test[:10]

plt.figure(figsize=(20, 10))
plt.hist2d(y_test[:2000], np.array(tf.squeeze(y_pred))[:2000], bins=40, cmap='jet')
plt.colorbar()
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.show()
