# %% [markdown]
# <a href="https://colab.research.google.com/github/GarettGazay/ai_projects/blob/master/RBSeq2Seq_Train_Loop_GRU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 0. Understand the predictions better, what are are these vectors it returns? A: They are the model's attempt at becoming the target.
#
# 1. Verify the input and target data are in fact the same data with the input shuffled and the target in the correct order.
#
# 2. Use the padding function to pad each batch to the correct dims (125,12)
#
# 3. Take 2 random days out of the data and convert it into a validation set, then try to implement early stopping.
#
# 4. Mini-batch train so the model can learn more and perhaps become better at predictions.
#
# 5. If training on more data does not improve the model, try looking at the data to see if there should be more, different, or less.
#
# ### Prediction
#
# - Correlate the predicted values with the input dataframe with headers, try to place the input data in order in a df with the predictions.
#
# - Find the most closely related (prediction, rides) values and arrange them according to the prediction order.
#
# - Walk through by creating a loop where we check for highest similarity between each ride in input_data and the predictions. Then order the rides in line with the predictions that way so it finds the most similar ride in inputs starting at the top of the predictions list.
#
# - Getting some correct results, but many are still out of order.
#
# - Check the accuracy of top 5 similarities
#
# - It could be that the predictions are accurate to the the targets, but with cos_similiarity, but they are still not accurate to predict on the input data.
#
# - May need to continue training the model to get better predictions.
#
# - May need to train on more data to learn the human decision making rhythms and nuances to find the correct orderings.
#
# - Thinking about this in terms of seq2seq, the model might not be very good at generalizing order of a single sequence having only trained on a single sequence. It may be that by training on many sequences, it will learn the nuance that guides it toward robust predictions.

# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import time

# %%
rides = pd.read_csv('/content/run_103.csv')

# %%
rides = rides.drop(['Unnamed: 0',
                    'order',
                    'rider.first_name',
                    'rider.last_name',
                    'pickup.event_location.address1',
                    'dropoff.event_location.address1',
                    'run_name_id',
                    'pickup_time',
                    ], axis=1)

# %%
rides.head()
# Out:
#    space_type  billable_distance  run_name  rider.mediroutes_rider_id  \
# 0    1.000000           0.020619       0.0                   0.045455
# 1    0.333333           0.005055       0.0                   0.257576
# 2    1.000000           0.007725       0.0                   0.515151
# 3    0.333333           0.062177       0.0                   0.272727
# 4    0.333333           0.013177       0.0                   0.151515
#
#    pickup.event_location.zip  pickup.event_location.longitude  \
# 0                   0.300000                        -0.996971
# 1                   0.600000                        -0.996493
# 2                   0.600000                        -0.996372
# 3                   0.333333                        -0.993221
# 4                   0.466667                        -0.995843
#
#    pickup.event_location.latitude  dropoff.event_location.zip  \
# 0                        0.993242                     0.03125
# 1                        0.993262                     0.81250
# 2                        0.992653                     0.81250
# 3                        0.985946                     0.59375
# 4                        0.993297                     0.81250
#
#    dropoff.event_location.longitude  dropoff.event_location.latitude  \
# 0                         -0.997400                         0.994884
# 1                         -0.996241                         0.993313
# 2                         -0.996193                         0.992977
# 3                         -0.994925                         0.990800
# 4                         -0.996241                         0.993314
#
#    pickup_month  pickup_day  pickup_hour  pickup_minute
# 0           1.0         2.0     0.000000       1.000000
# 1           1.0         2.0     0.083333       0.333333
# 2           1.0         2.0     0.166667       0.000000
# 3           1.0         2.0     0.333333       0.000000
# 4           1.0         2.0     0.416667       0.000000

# %%
rides = rides.astype('float32')

# %%
# Count the number of NaN values in each column
nan_counts = rides.isna().sum()

# Display the count of NaN values for each column
print(nan_counts)
# Out:
# space_type                          0
# billable_distance                   0
# run_name                            0
# rider.mediroutes_rider_id           0
# pickup.event_location.zip           0
# pickup.event_location.longitude     0
# pickup.event_location.latitude      0
# dropoff.event_location.zip          0
# dropoff.event_location.longitude    0
# dropoff.event_location.latitude     0
# pickup_month                        0
# pickup_day                          0
# pickup_hour                         0
# pickup_minute                       0
# dtype: int64

# %%
rides.fillna(0, inplace=True)

# %%
rides.dtypes
# Out:
# space_type                          float32
# billable_distance                   float32
# run_name                            float32
# rider.mediroutes_rider_id           float32
# pickup.event_location.zip           float32
# pickup.event_location.longitude     float32
# pickup.event_location.latitude      float32
# dropoff.event_location.zip          float32
# dropoff.event_location.longitude    float32
# dropoff.event_location.latitude     float32
# pickup_month                        float32
# pickup_day                          float32
# pickup_hour                         float32
# pickup_minute                       float32
# dtype: object

# %%
rides.head()
# Out:
#    space_type  billable_distance  run_name  rider.mediroutes_rider_id  \
# 0    1.000000           0.020619       0.0                   0.045455
# 1    0.333333           0.005055       0.0                   0.257576
# 2    1.000000           0.007725       0.0                   0.515152
# 3    0.333333           0.062177       0.0                   0.272727
# 4    0.333333           0.013177       0.0                   0.151515
#
#    pickup.event_location.zip  pickup.event_location.longitude  \
# 0                   0.300000                        -0.996971
# 1                   0.600000                        -0.996493
# 2                   0.600000                        -0.996372
# 3                   0.333333                        -0.993221
# 4                   0.466667                        -0.995843
#
#    pickup.event_location.latitude  dropoff.event_location.zip  \
# 0                        0.993242                     0.03125
# 1                        0.993262                     0.81250
# 2                        0.992653                     0.81250
# 3                        0.985946                     0.59375
# 4                        0.993297                     0.81250
#
#    dropoff.event_location.longitude  dropoff.event_location.latitude  \
# 0                         -0.997400                         0.994884
# 1                         -0.996241                         0.993313
# 2                         -0.996193                         0.992977
# 3                         -0.994925                         0.990800
# 4                         -0.996241                         0.993314
#
#    pickup_month  pickup_day  pickup_hour  pickup_minute
# 0           1.0         2.0     0.000000       1.000000
# 1           1.0         2.0     0.083333       0.333333
# 2           1.0         2.0     0.166667       0.000000
# 3           1.0         2.0     0.333333       0.000000
# 4           1.0         2.0     0.416667       0.000000

# %%
counts = rides.groupby(['pickup_month', 'pickup_day']).size().reset_index(name='counts')
counts['counts'].mean()
# Out:
# 9.357142857142858

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 7))

import matplotlib.pyplot as plt
import numpy as np

# Calculate the mean and standard deviation of the counts column
mean = counts['counts'].mean()
std = counts['counts'].std()

# Plot the histogram of the counts column
counts['counts'].hist(bins=20)

# Add vertical lines to indicate mean and standard deviation
plt.axvline(mean, color='red', label='Mean')
plt.axvline(mean + std, color='blue', label='+1 Standard Deviation')
plt.axvline(mean - std, color='blue', label='-1 Standard Deviation')

# Add title and labels
plt.title('Distribution of Counts Column')
plt.xlabel('Counts')
plt.ylabel('Frequency')
plt.legend()

# Show plot
plt.show()

# %%
rides['pickup_day'] = rides['pickup_day'].fillna(0).astype(int)
rides['pickup_month'] = rides['pickup_month'].fillna(0).astype(int)

rides['pickup_day'] = rides['pickup_day'].astype(str)
rides['pickup_month'] = rides['pickup_month'].astype(str)

rides['id'] = rides['pickup_month'] + rides['pickup_day']

rides = rides.drop(['pickup_month','pickup_day'], axis=1)

# %%
rides.head()
# Out:
#    space_type  billable_distance  run_name  rider.mediroutes_rider_id  \
# 0    1.000000           0.020619       0.0                   0.045455
# 1    0.333333           0.005055       0.0                   0.257576
# 2    1.000000           0.007725       0.0                   0.515152
# 3    0.333333           0.062177       0.0                   0.272727
# 4    0.333333           0.013177       0.0                   0.151515
#
#    pickup.event_location.zip  pickup.event_location.longitude  \
# 0                   0.300000                        -0.996971
# 1                   0.600000                        -0.996493
# 2                   0.600000                        -0.996372
# 3                   0.333333                        -0.993221
# 4                   0.466667                        -0.995843
#
#    pickup.event_location.latitude  dropoff.event_location.zip  \
# 0                        0.993242                     0.03125
# 1                        0.993262                     0.81250
# 2                        0.992653                     0.81250
# 3                        0.985946                     0.59375
# 4                        0.993297                     0.81250
#
#    dropoff.event_location.longitude  dropoff.event_location.latitude  \
# 0                         -0.997400                         0.994884
# 1                         -0.996241                         0.993313
# 2                         -0.996193                         0.992977
# 3                         -0.994925                         0.990800
# 4                         -0.996241                         0.993314
#
#    pickup_hour  pickup_minute  id
# 0     0.000000       1.000000  12
# 1     0.083333       0.333333  12
# 2     0.166667       0.000000  12
# 3     0.333333       0.000000  12
# 4     0.416667       0.000000  12

# %%
rides.shape
# Out:
# (262, 13)

# %%
rides = rides.astype(str)

# %%
rides.values[0].astype('float32')
# Out:
# array([ 1.        ,  0.02061856,  0.        ,  0.04545455,  0.3       ,
#        -0.99697095,  0.9932419 ,  0.03125   , -0.9973999 ,  0.99488443,
#         0.        ,  1.        , 12.        ], dtype=float32)

# %% [markdown]
# # DAY NUMBER WE ARE TRAINING - SET IT HERE FOR ALL BELOW CODE

# %%
len(max(rides, key=len))
# Out:
# 32

# %%
day_of_rides = 0
sequence_len = 13

# %% [markdown]
# Put rides into buckets by date

# %%
# Group the rows by the 'id' column
grouped = rides.groupby('id')

# Create a list to store the grouped arrays
day_buckets = []

# Loop through each group
for name, group in grouped:
    # Convert the group to a numpy array
    group_array = group.values.astype(np.float32)
    
    # Append the group array to the list of grouped arrays
    day_buckets.append(group_array)

# Set the display format of the numpy arrays
np.set_printoptions(precision=6, suppress=True)

# Sort the list of grouped arrays by the first column of each array
day_buckets.sort(key=lambda x: x[0][1])

# %%
# Do this or when you shuffle below it will shuffle both for some fucking reason, and copy doesn't work.
day_buckets_y = [x.astype(str) for x in day_buckets[1:]]

# %%
len(day_buckets_y[9])
# Out:
# 12

# %%
# Get a look at the run's unique day/schedule lengths for each day in the year.
unique_lengths = list(set(len(sub_array) for sub_array in day_buckets_y))

# %%
unique_lengths
# Out:
# [5, 6, 8, 9, 10, 11, 12, 13]

# %%
day_buckets_y[0]
# Out:
# array([['1.0', '0.020550499', '0.0', '0.045454547', '0.3', '-0.99697095',
#         '0.9932419', '0.03125', '-0.9973999', '0.99488443', '0.0', '1.0',
#         '110.0'],
#        ['0.33333334', '0.019966312', '0.0', '0.21212122', '0.26666668',
#         '-0.99644196', '0.9920201', '0.5625', '-0.9958683', '0.9912264',
#         '0.083333336', '1.0', '110.0'],
#        ['0.0', '0.050601106', '0.0', '0.10606061', '0.2', '-0.9980458',
#         '0.9966702', '0.375', '-0.9967102', '0.9936471', '0.25', '1.0',
#         '110.0'],
#        ['1.0', '0.02990315', '0.0', '0.22727273', '0.8666667',
#         '-0.99619335', '0.992977', '0.96875', '-0.99613476',
#         '0.99532086', '0.41666666', '0.6666667', '110.0'],
#        ['1.0', '0.012014573', '0.0', '0.43939394', '0.8666667',
#         '-0.99619335', '0.992977', '0.71875', '-0.9958649', '0.99306273',
#         '0.41666666', '0.6666667', '110.0'],
#        ['1.0', '0.0021703742', '0.0', '0.3030303', '0.6', '-0.9964902',
#         '0.99326324', '0.59375', '-0.99658185', '0.99327487', '0.5',
#         '0.6666667', '110.0'],
#        ['1.0', '0.01565014', '0.0', '0.57575756', '0.56666666',
#         '-0.9955298', '0.9943158', '0.625', '-0.99534154', '0.9931722',
#         '0.5833333', '0.44444445', '110.0'],
#        ['1.0', '0.012727319', '0.0', '0.030303031', '0.6666667',
#         '-0.9953415', '0.99317205', '0.5', '-0.9955119', '0.9942838',
#         '0.75', '0.33333334', '110.0']], dtype='<U32')

# %%
def shuffle_np_array(np_array_list):
    for i in range(len(np_array_list)):
        np.random.shuffle(np_array_list[i])
    return np_array_list

day_buckets_X = shuffle_np_array(day_buckets)[1:] # create a shuffled version for X below

# %%
input = []
target = []
for array in day_buckets_X:
    new_array = np.delete(array, -1, axis=1)
    input.append(new_array.astype('float32'))

count = 0
for array in day_buckets_y:
    new_array = np.delete(array, -1, axis=1)
    target.append(new_array.astype('float32'))

# %% [markdown]
# # Load the model for the training loop

# %%
# Set early stopping
from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=5)

# %%
# Create a TensorBoard callback
import datetime

logdir = "/content/drive/MyDrive/tensorboard_logs" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
def pad_array(arr):

    padding = np.zeros((1, 12))
    while arr.shape[0] < sequence_len:
        arr = np.concatenate((arr, padding), axis=0)
    return arr

def create_validation_set():
  random_validation_set = np.random.randint(0, len(day_buckets_X))

  if not random_validation_set == day_of_rides:
    print('random_validation_set: ', random_validation_set)
    print('day_of_rides: ', day_of_rides)
    X_val = input[-1].astype('float32')
    X_val = pad_array(X_val)

    y_val = target[-1].astype('float32')
    y_val = pad_array(y_val)

    return X_val, y_val
  else:
    # Recursively call the function until it lands on a random day of rides that doesn't match the training tensor.
    create_validation_set()

# %% [markdown]
# In this example, an attention mechanism is added to the decoder by creating an Attention layer, which takes in the decoder outputs and encoder outputs, and returns the attention-weighted representation of the decoder outputs. This attention-weighted representation is then passed through a dense layer to make the final predictions.
#
# This is just one way to implement attention mechanism, there are other ways as well.

# %%
# dummy = np.zeros((1,200,12))
# dummy.shape
# pred = model.predict([input_, dummy])

# pred[0][1]

# %%
first_run = False

# TRAINING LOOP
start_at = 1
train_until = 30
for day_of_rides in range(start_at, train_until): # num days to be trained

  if not first_run:
    print(f'Training {day_of_rides} of {train_until}')
    model = keras.models.load_model('/content/drive/MyDrive/Colab_Models/RBSeq2Seq')

  # Pad the input
  input[day_of_rides] = pad_array(input[day_of_rides])
  target[day_of_rides] = pad_array(target[day_of_rides])

  # print(pad_array(input[day_of_rides]))

  # Truncate input to defined sequence length
  input[day_of_rides] = input[day_of_rides][:sequence_len]
  target[day_of_rides] = target[day_of_rides][:sequence_len]

  # Create Random Validation Set
  X_val, y_val = create_validation_set()

  # Create Input and Target Df's
  input_df = pd.DataFrame(input[day_of_rides], columns=[
  'input_space_type',
  'input_billable_distance',
  'input_run_name',
  'input_rider.mediroutes_rider_id',
  'input_pickup.event_location.zip',
  'input_pickup.event_location.longitude',
  'input_pickup.event_location.latitude',
  'input_dropoff.event_location.zip',
  'input_dropoff.event_location.longitude',
  'input_dropoff.event_location.latitude',
  'input_pickup_hour',
  'input_pickup_minute'
  ])

  target_df = pd.DataFrame(target[day_of_rides], columns=[
  'target_space_type',
  'target_billable_distance',
  'target_run_name',
  'target_rider.mediroutes_rider_id',
  'target_pickup.event_location.zip',
  'target_pickup.event_location.longitude',
  'target_pickup.event_location.latitude',
  'target_dropoff.event_location.zip',
  'target_dropoff.event_location.longitude',
  'target_dropoff.event_location.latitude',
  'target_pickup_hour',
  'target_pickup_minute'
  ])

  # Define the input and output shape
  input_shape = (sequence_len, 12)
  output_shape = (sequence_len, 12)

  # Set the input and target to the day of rides iteration
  input_orig = input[day_of_rides]
  target_orig = target[day_of_rides]

  input_ = input_orig.reshape(1, *input_orig.shape)
  target_ = target_orig.reshape(1, *target_orig.shape)
  X_val = X_val.reshape(1, *X_val.shape)
  y_val = y_val.reshape(1, *y_val.shape)

  print(input_.shape)
  print(input_.shape)
  print(X_val.shape)
  print(y_val.shape)


  # Define the model architecture
  inputs = keras.layers.Input(shape=(None, 12))
  encoder = keras.layers.GRU(128, return_state=True)
  encoder_outputs, state_h = encoder(inputs)
  encoder_states = [state_h]

  decoder = keras.layers.GRU(128, return_sequences=True)
  decoder_outputs = decoder(inputs, initial_state=encoder_states)

  outputs = keras.layers.Dense(12, activation='linear')(decoder_outputs)

  if first_run:
    model = keras.models.Model(inputs=inputs, outputs=outputs)
    # Compile the model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
                  loss=tf.keras.losses.mse)
    print('Training first run.')
  
  # Train the model
  history = model.fit(input_, target_, epochs=400, batch_size=32, validation_data=(X_val, y_val), callbacks=[early_stopping], verbose=2)
  print('Saving model.')
  model.save('/content/drive/MyDrive/Colab_Models/RBSeq2Seq')
# Out:
# Training 1 of 30
# random_validation_set:  19
# day_of_rides:  1
# (1, 13, 12)
# (1, 13, 12)
# (1, 13, 12)
# (1, 13, 12)
# Epoch 1/400
# 1/1 - 7s - loss: 0.0580 - val_loss: 0.0686 - 7s/epoch - 7s/step
# Epoch 2/400
# 1/1 - 0s - loss: 0.0557 - val_loss: 0.0674 - 50ms/epoch - 50ms/step
# Epoch 3/400
# 1/1 - 0s - loss: 0.0536 - val_loss: 0.0663 - 52ms/epoch - 52ms/step
# Epoch 4/400
# 1/1 - 0s - loss: 0.0517 - val_loss: 0.0655 - 45ms/epoch - 45ms/step
# Epoch 5/400
# 1/1 - 0s - loss: 0.0501 - val_loss: 0.0649 - 48ms/epoch - 48ms/step
# Epoch 6/400
# 1/1 - 0s - loss: 0.0488 - val_loss: 0.0644 - 49ms/epoch - 49ms/step
# Epoch 7/400
# 1/1 - 0s - loss: 0.0476 - val_loss: 0.0641 - 47ms/epoch - 47ms/step
# Epoch 8/400
# 1/1 - 0s - loss: 0.0467 - val_loss: 0.0639 - 49ms/epoch - 49ms/step
# Epoch 9/400
# 1/1 - 0s - loss: 0.0459 - val_loss: 0.0637 - 52ms/epoch - 52ms/step
# Epoch 10/400
# 1/1 - 0s - loss: 0.0452 - val_loss: 0.0636 - 59ms/epoch - 59ms/step
# Epoch 11/400
# 1/1 - 0s - loss: 0.0446 - val_loss: 0.0635 - 66ms/epoch - 66ms/step
# Epoch 12/400
# 1/1 - 0s - loss: 0.0442 - val_loss: 0.0633 - 68ms/epoch - 68ms/step
# Epoch 13/400
# 1/1 - 0s - loss: 0.0437 - val_loss: 0.0632 - 48ms/epoch - 48ms/step
# Epoch 14/400
# 1/1 - 0s - loss: 0.0434 - val_loss: 0.0630 - 51ms/epoch - 51ms/step
# Epoch 15/400
# 1/1 - 0s - loss: 0.0431 - val_loss: 0.0628 - 52ms/epoch - 52ms/step
# Epoch 16/400
# 1/1 - 0s - loss: 0.0427 - val_loss: 0.0625 - 51ms/epoch - 51ms/step
# Epoch 17/400
# 1/1 - 0s - loss: 0.0424 - val_loss: 0.0623 - 55ms/epoch - 55ms/step
# Epoch 18/400
# 1/1 - 0s - loss: 0.0422 - val_loss: 0.0620 - 50ms/epoch - 50ms/step
# Epoch 19/400
# 1/1 - 0s - loss: 0.0419 - val_loss: 0.0617 - 54ms/epoch - 54ms/step
# Epoch 20/400
# 1/1 - 0s - loss: 0.0416 - val_loss: 0.0613 - 50ms/epoch - 50ms/step
# Epoch 21/400
# 1/1 - 0s - loss: 0.0413 - val_loss: 0.0610 - 50ms/epoch - 50ms/step
# Epoch 22/400
# 1/1 - 0s - loss: 0.0411 - val_loss: 0.0607 - 48ms/epoch - 48ms/step
# Epoch 23/400
# 1/1 - 0s - loss: 0.0408 - val_loss: 0.0604 - 50ms/epoch - 50ms/step
# Epoch 24/400
# 1/1 - 0s - loss: 0.0405 - val_loss: 0.0601 - 53ms/epoch - 53ms/step
# Epoch 25/400
# 1/1 - 0s - loss: 0.0403 - val_loss: 0.0598 - 68ms/epoch - 68ms/step
# Epoch 26/400
# 1/1 - 0s - loss: 0.0400 - val_loss: 0.0595 - 52ms/epoch - 52ms/step
# Epoch 27/400
# 1/1 - 0s - loss: 0.0398 - val_loss: 0.0593 - 58ms/epoch - 58ms/step
# Epoch 28/400
# 1/1 - 0s - loss: 0.0396 - val_loss: 0.0590 - 55ms/epoch - 55ms/step
# Epoch 29/400
# 1/1 - 0s - loss: 0.0393 - val_loss: 0.0588 - 67ms/epoch - 67ms/step
# Epoch 30/400
# 1/1 - 0s - loss: 0.0391 - val_loss: 0.0586 - 52ms/epoch - 52ms/step
# Epoch 31/400
# 1/1 - 0s - loss: 0.0389 - val_loss: 0.0584 - 50ms/epoch - 50ms/step
# Epoch 32/400
# 1/1 - 0s - loss: 0.0387 - val_loss: 0.0582 - 50ms/epoch - 50ms/step
# Epoch 33/400
# 1/1 - 0s - loss: 0.0385 - val_loss: 0.0579 - 65ms/epoch - 65ms/step
# Epoch 34/400
# 1/1 - 0s - loss: 0.0383 - val_loss: 0.0577 - 54ms/epoch - 54ms/step
# Epoch 35/400
# 1/1 - 0s - loss: 0.0381 - val_loss: 0.0575 - 49ms/epoch - 49ms/step
# Epoch 36/400
# 1/1 - 0s - loss: 0.0379 - val_loss: 0.0573 - 51ms/epoch - 51ms/step
# Epoch 37/400
# 1/1 - 0s - loss: 0.0377 - val_loss: 0.0571 - 55ms/epoch - 55ms/step
# Epoch 38/400
# 1/1 - 0s - loss: 0.0375 - val_loss: 0.0569 - 55ms/epoch - 55ms/step
# Epoch 39/400
# 1/1 - 0s - loss: 0.0373 - val_loss: 0.0567 - 52ms/epoch - 52ms/step
# Epoch 40/400
# 1/1 - 0s - loss: 0.0371 - val_loss: 0.0564 - 49ms/epoch - 49ms/step
# Epoch 41/400
# 1/1 - 0s - loss: 0.0369 - val_loss: 0.0562 - 49ms/epoch - 49ms/step
# Epoch 42/400
# 1/1 - 0s - loss: 0.0367 - val_loss: 0.0560 - 53ms/epoch - 53ms/step
# Epoch 43/400
# 1/1 - 0s - loss: 0.0365 - val_loss: 0.0558 - 50ms/epoch - 50ms/step
# Epoch 44/400
# 1/1 - 0s - loss: 0.0363 - val_loss: 0.0556 - 48ms/epoch - 48ms/step
# Epoch 45/400
# 1/1 - 0s - loss: 0.0361 - val_loss: 0.0553 - 58ms/epoch - 58ms/step
# Epoch 46/400
# 1/1 - 0s - loss: 0.0359 - val_loss: 0.0551 - 49ms/epoch - 49ms/step
# Epoch 47/400
# 1/1 - 0s - loss: 0.0357 - val_loss: 0.0549 - 48ms/epoch - 48ms/step
# Epoch 48/400
# 1/1 - 0s - loss: 0.0356 - val_loss: 0.0547 - 50ms/epoch - 50ms/step
# Epoch 49/400
# 1/1 - 0s - loss: 0.0354 - val_loss: 0.0545 - 53ms/epoch - 53ms/step
# Epoch 50/400
# 1/1 - 0s - loss: 0.0352 - val_loss: 0.0543 - 56ms/epoch - 56ms/step
# Epoch 51/400
# 1/1 - 0s - loss: 0.0350 - val_loss: 0.0541 - 49ms/epoch - 49ms/step
# Epoch 52/400
# 1/1 - 0s - loss: 0.0348 - val_loss: 0.0539 - 62ms/epoch - 62ms/step
# Epoch 53/400
# 1/1 - 0s - loss: 0.0346 - val_loss: 0.0537 - 52ms/epoch - 52ms/step
# Epoch 54/400
# 1/1 - 0s - loss: 0.0345 - val_loss: 0.0535 - 49ms/epoch - 49ms/step
# Epoch 55/400
# 1/1 - 0s - loss: 0.0343 - val_loss: 0.0534 - 49ms/epoch - 49ms/step
# Epoch 56/400
# 1/1 - 0s - loss: 0.0341 - val_loss: 0.0532 - 50ms/epoch - 50ms/step
# Epoch 57/400
# 1/1 - 0s - loss: 0.0339 - val_loss: 0.0531 - 52ms/epoch - 52ms/step
# Epoch 58/400
# 1/1 - 0s - loss: 0.0338 - val_loss: 0.0529 - 51ms/epoch - 51ms/step
# Epoch 59/400
# 1/1 - 0s - loss: 0.0336 - val_loss: 0.0528 - 51ms/epoch - 51ms/step
# Epoch 60/400
# 1/1 - 0s - loss: 0.0334 - val_loss: 0.0526 - 49ms/epoch - 49ms/step
# Epoch 61/400
# 1/1 - 0s - loss: 0.0332 - val_loss: 0.0525 - 52ms/epoch - 52ms/step
# Epoch 62/400
# 1/1 - 0s - loss: 0.0331 - val_loss: 0.0524 - 49ms/epoch - 49ms/step
# Epoch 63/400
# 1/1 - 0s - loss: 0.0329 - val_loss: 0.0523 - 57ms/epoch - 57ms/step
# Epoch 64/400
# 1/1 - 0s - loss: 0.0327 - val_loss: 0.0521 - 49ms/epoch - 49ms/step
# Epoch 65/400
# 1/1 - 0s - loss: 0.0326 - val_loss: 0.0520 - 50ms/epoch - 50ms/step
# Epoch 66/400
# 1/1 - 0s - loss: 0.0324 - val_loss: 0.0519 - 50ms/epoch - 50ms/step
# Epoch 67/400
# 1/1 - 0s - loss: 0.0322 - val_loss: 0.0518 - 65ms/epoch - 65ms/step
# Epoch 68/400
# 1/1 - 0s - loss: 0.0321 - val_loss: 0.0516 - 52ms/epoch - 52ms/step
# Epoch 69/400
# 1/1 - 0s - loss: 0.0319 - val_loss: 0.0515 - 50ms/epoch - 50ms/step
# Epoch 70/400
# 1/1 - 0s - loss: 0.0317 - val_loss: 0.0514 - 49ms/epoch - 49ms/step
# Epoch 71/400
# 1/1 - 0s - loss: 0.0316 - val_loss: 0.0513 - 52ms/epoch - 52ms/step
# Epoch 72/400
# 1/1 - 0s - loss: 0.0314 - val_loss: 0.0511 - 53ms/epoch - 53ms/step
# Epoch 73/400
# 1/1 - 0s - loss: 0.0312 - val_loss: 0.0510 - 49ms/epoch - 49ms/step
# Epoch 74/400
# 1/1 - 0s - loss: 0.0311 - val_loss: 0.0509 - 49ms/epoch - 49ms/step
# Epoch 75/400
# 1/1 - 0s - loss: 0.0309 - val_loss: 0.0507 - 50ms/epoch - 50ms/step
# Epoch 76/400
# 1/1 - 0s - loss: 0.0307 - val_loss: 0.0506 - 53ms/epoch - 53ms/step
# Epoch 77/400
# 1/1 - 0s - loss: 0.0306 - val_loss: 0.0505 - 49ms/epoch - 49ms/step
# Epoch 78/400
# 1/1 - 0s - loss: 0.0304 - val_loss: 0.0504 - 66ms/epoch - 66ms/step
# Epoch 79/400
# 1/1 - 0s - loss: 0.0303 - val_loss: 0.0502 - 52ms/epoch - 52ms/step
# Epoch 80/400
# 1/1 - 0s - loss: 0.0301 - val_loss: 0.0501 - 49ms/epoch - 49ms/step
# Epoch 81/400
# 1/1 - 0s - loss: 0.0299 - val_loss: 0.0500 - 57ms/epoch - 57ms/step
# Epoch 82/400
# 1/1 - 0s - loss: 0.0298 - val_loss: 0.0499 - 48ms/epoch - 48ms/step
# Epoch 83/400
# 1/1 - 0s - loss: 0.0296 - val_loss: 0.0498 - 58ms/epoch - 58ms/step
# Epoch 84/400
# 1/1 - 0s - loss: 0.0295 - val_loss: 0.0497 - 67ms/epoch - 67ms/step
# Epoch 85/400
# 1/1 - 0s - loss: 0.0293 - val_loss: 0.0496 - 57ms/epoch - 57ms/step
# Epoch 86/400
# 1/1 - 0s - loss: 0.0291 - val_loss: 0.0495 - 62ms/epoch - 62ms/step
# Epoch 87/400
# 1/1 - 0s - loss: 0.0290 - val_loss: 0.0494 - 52ms/epoch - 52ms/step
# Epoch 88/400
# 1/1 - 0s - loss: 0.0288 - val_loss: 0.0493 - 52ms/epoch - 52ms/step
# Epoch 89/400
# 1/1 - 0s - loss: 0.0287 - val_loss: 0.0492 - 48ms/epoch - 48ms/step
# Epoch 90/400
# 1/1 - 0s - loss: 0.0285 - val_loss: 0.0491 - 50ms/epoch - 50ms/step
# Epoch 91/400
# 1/1 - 0s - loss: 0.0284 - val_loss: 0.0490 - 51ms/epoch - 51ms/step
# Epoch 92/400
# 1/1 - 0s - loss: 0.0282 - val_loss: 0.0489 - 48ms/epoch - 48ms/step
# Epoch 93/400
# 1/1 - 0s - loss: 0.0280 - val_loss: 0.0488 - 49ms/epoch - 49ms/step
# Epoch 94/400
# 1/1 - 0s - loss: 0.0279 - val_loss: 0.0487 - 55ms/epoch - 55ms/step
# Epoch 95/400
# 1/1 - 0s - loss: 0.0277 - val_loss: 0.0486 - 55ms/epoch - 55ms/step
# Epoch 96/400
# 1/1 - 0s - loss: 0.0276 - val_loss: 0.0486 - 57ms/epoch - 57ms/step
# Epoch 97/400
# 1/1 - 0s - loss: 0.0274 - val_loss: 0.0485 - 66ms/epoch - 66ms/step
# Epoch 98/400
# 1/1 - 0s - loss: 0.0273 - val_loss: 0.0484 - 85ms/epoch - 85ms/step
# Epoch 99/400
# 1/1 - 0s - loss: 0.0271 - val_loss: 0.0483 - 52ms/epoch - 52ms/step
# Epoch 100/400
# 1/1 - 0s - loss: 0.0270 - val_loss: 0.0482 - 48ms/epoch - 48ms/step
# Epoch 101/400
# 1/1 - 0s - loss: 0.0268 - val_loss: 0.0482 - 49ms/epoch - 49ms/step
# Epoch 102/400
# 1/1 - 0s - loss: 0.0267 - val_loss: 0.0481 - 51ms/epoch - 51ms/step
# Epoch 103/400
# 1/1 - 0s - loss: 0.0265 - val_loss: 0.0480 - 48ms/epoch - 48ms/step
# Epoch 104/400
# 1/1 - 0s - loss: 0.0264 - val_loss: 0.0479 - 52ms/epoch - 52ms/step
# Epoch 105/400
# 1/1 - 0s - loss: 0.0262 - val_loss: 0.0479 - 51ms/epoch - 51ms/step
# Epoch 106/400
# 1/1 - 0s - loss: 0.0261 - val_loss: 0.0478 - 55ms/epoch - 55ms/step
# Epoch 107/400
# 1/1 - 0s - loss: 0.0259 - val_loss: 0.0477 - 52ms/epoch - 52ms/step
# Epoch 108/400
# 1/1 - 0s - loss: 0.0258 - val_loss: 0.0477 - 60ms/epoch - 60ms/step
# Epoch 109/400
# 1/1 - 0s - loss: 0.0256 - val_loss: 0.0476 - 52ms/epoch - 52ms/step
# Epoch 110/400
# 1/1 - 0s - loss: 0.0254 - val_loss: 0.0476 - 53ms/epoch - 53ms/step
# Epoch 111/400
# 1/1 - 0s - loss: 0.0253 - val_loss: 0.0475 - 58ms/epoch - 58ms/step
# Epoch 112/400
# 1/1 - 0s - loss: 0.0251 - val_loss: 0.0474 - 59ms/epoch - 59ms/step
# Epoch 113/400
# 1/1 - 0s - loss: 0.0250 - val_loss: 0.0474 - 66ms/epoch - 66ms/step
# Epoch 114/400
# 1/1 - 0s - loss: 0.0248 - val_loss: 0.0473 - 93ms/epoch - 93ms/step
# Epoch 115/400
# 1/1 - 0s - loss: 0.0247 - val_loss: 0.0473 - 109ms/epoch - 109ms/step
# Epoch 116/400
# 1/1 - 0s - loss: 0.0245 - val_loss: 0.0472 - 98ms/epoch - 98ms/step
# Epoch 117/400
# 1/1 - 0s - loss: 0.0244 - val_loss: 0.0472 - 98ms/epoch - 98ms/step
# Epoch 118/400
# 1/1 - 0s - loss: 0.0242 - val_loss: 0.0471 - 101ms/epoch - 101ms/step
# Epoch 119/400
# 1/1 - 0s - loss: 0.0241 - val_loss: 0.0471 - 101ms/epoch - 101ms/step
# Epoch 120/400
# 1/1 - 0s - loss: 0.0239 - val_loss: 0.0470 - 86ms/epoch - 86ms/step
# Epoch 121/400
# 1/1 - 0s - loss: 0.0238 - val_loss: 0.0470 - 84ms/epoch - 84ms/step
# Epoch 122/400
# 1/1 - 0s - loss: 0.0236 - val_loss: 0.0469 - 81ms/epoch - 81ms/step
# Epoch 123/400
# 1/1 - 0s - loss: 0.0235 - val_loss: 0.0469 - 83ms/epoch - 83ms/step
# Epoch 124/400
# 1/1 - 0s - loss: 0.0233 - val_loss: 0.0468 - 82ms/epoch - 82ms/step
# Epoch 125/400
# 1/1 - 0s - loss: 0.0232 - val_loss: 0.0468 - 96ms/epoch - 96ms/step
# Epoch 126/400
# 1/1 - 0s - loss: 0.0230 - val_loss: 0.0467 - 105ms/epoch - 105ms/step
# Epoch 127/400
# 1/1 - 0s - loss: 0.0229 - val_loss: 0.0467 - 84ms/epoch - 84ms/step
# Epoch 128/400
# 1/1 - 0s - loss: 0.0227 - val_loss: 0.0467 - 83ms/epoch - 83ms/step
# Epoch 129/400
# 1/1 - 0s - loss: 0.0226 - val_loss: 0.0466 - 84ms/epoch - 84ms/step
# Epoch 130/400
# 1/1 - 0s - loss: 0.0224 - val_loss: 0.0466 - 85ms/epoch - 85ms/step
# Epoch 131/400
# 1/1 - 0s - loss: 0.0223 - val_loss: 0.0465 - 87ms/epoch - 87ms/step
# Epoch 132/400
# 1/1 - 0s - loss: 0.0222 - val_loss: 0.0465 - 86ms/epoch - 86ms/step
# Epoch 133/400
# 1/1 - 0s - loss: 0.0220 - val_loss: 0.0465 - 90ms/epoch - 90ms/step
# Epoch 134/400
# 1/1 - 0s - loss: 0.0219 - val_loss: 0.0464 - 102ms/epoch - 102ms/step
# Epoch 135/400
# 1/1 - 0s - loss: 0.0217 - val_loss: 0.0464 - 82ms/epoch - 82ms/step
# Epoch 136/400
# 1/1 - 0s - loss: 0.0216 - val_loss: 0.0464 - 83ms/epoch - 83ms/step
# Epoch 137/400
# 1/1 - 0s - loss: 0.0214 - val_loss: 0.0464 - 106ms/epoch - 106ms/step
# Epoch 138/400
# 1/1 - 0s - loss: 0.0213 - val_loss: 0.0463 - 96ms/epoch - 96ms/step
# Epoch 139/400
# 1/1 - 0s - loss: 0.0211 - val_loss: 0.0463 - 99ms/epoch - 99ms/step
# Epoch 140/400
# 1/1 - 0s - loss: 0.0210 - val_loss: 0.0463 - 111ms/epoch - 111ms/step
# Epoch 141/400
# 1/1 - 0s - loss: 0.0208 - val_loss: 0.0463 - 94ms/epoch - 94ms/step
# Epoch 142/400
# 1/1 - 0s - loss: 0.0207 - val_loss: 0.0462 - 59ms/epoch - 59ms/step
# Epoch 143/400
# 1/1 - 0s - loss: 0.0205 - val_loss: 0.0462 - 68ms/epoch - 68ms/step
# Epoch 144/400
# 1/1 - 0s - loss: 0.0204 - val_loss: 0.0462 - 52ms/epoch - 52ms/step
# Epoch 145/400
# 1/1 - 0s - loss: 0.0203 - val_loss: 0.0462 - 49ms/epoch - 49ms/step
# Epoch 146/400
# 1/1 - 0s - loss: 0.0201 - val_loss: 0.0462 - 49ms/epoch - 49ms/step
# Epoch 147/400
# 1/1 - 0s - loss: 0.0200 - val_loss: 0.0461 - 49ms/epoch - 49ms/step
# Epoch 148/400
# 1/1 - 0s - loss: 0.0198 - val_loss: 0.0461 - 51ms/epoch - 51ms/step
# Epoch 149/400
# 1/1 - 0s - loss: 0.0197 - val_loss: 0.0461 - 47ms/epoch - 47ms/step
# Epoch 150/400
# 1/1 - 0s - loss: 0.0195 - val_loss: 0.0461 - 71ms/epoch - 71ms/step
# Epoch 151/400
# 1/1 - 0s - loss: 0.0194 - val_loss: 0.0461 - 69ms/epoch - 69ms/step
# Epoch 152/400
# 1/1 - 0s - loss: 0.0193 - val_loss: 0.0461 - 68ms/epoch - 68ms/step
# Epoch 153/400
# 1/1 - 0s - loss: 0.0191 - val_loss: 0.0461 - 49ms/epoch - 49ms/step
# Epoch 154/400
# 1/1 - 0s - loss: 0.0190 - val_loss: 0.0461 - 51ms/epoch - 51ms/step
# Epoch 155/400
# 1/1 - 0s - loss: 0.0189 - val_loss: 0.0461 - 67ms/epoch - 67ms/step
# Epoch 156/400
# 1/1 - 0s - loss: 0.0187 - val_loss: 0.0461 - 50ms/epoch - 50ms/step
# Epoch 157/400
# 1/1 - 0s - loss: 0.0186 - val_loss: 0.0461 - 54ms/epoch - 54ms/step
# Epoch 158/400
# 1/1 - 0s - loss: 0.0184 - val_loss: 0.0461 - 47ms/epoch - 47ms/step
# Epoch 159/400
# 1/1 - 0s - loss: 0.0183 - val_loss: 0.0461 - 49ms/epoch - 49ms/step
# Epoch 160/400
# 1/1 - 0s - loss: 0.0182 - val_loss: 0.0461 - 48ms/epoch - 48ms/step
# Epoch 161/400
# 1/1 - 0s - loss: 0.0181 - val_loss: 0.0461 - 49ms/epoch - 49ms/step
# Epoch 162/400
# 1/1 - 0s - loss: 0.0179 - val_loss: 0.0461 - 53ms/epoch - 53ms/step
# Saving model.
# WARNING:absl:Found untraced functions such as _update_step_xla, gru_cell_2_layer_call_fn, gru_cell_2_layer_call_and_return_conditional_losses, gru_cell_3_layer_call_fn, gru_cell_3_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# Training 2 of 30
# random_validation_set:  13
# day_of_rides:  2
# (1, 13, 12)
# (1, 13, 12)
# (1, 13, 12)
# (1, 13, 12)
# Epoch 1/400
# 1/1 - 6s - loss: 0.0254 - val_loss: 0.0447 - 6s/epoch - 6s/step
# Epoch 2/400
# 1/1 - 0s - loss: 0.0244 - val_loss: 0.0437 - 51ms/epoch - 51ms/step
# Epoch 3/400
# 1/1 - 0s - loss: 0.0236 - val_loss: 0.0431 - 54ms/epoch - 54ms/step
# Epoch 4/400
# 1/1 - 0s - loss: 0.0230 - val_loss: 0.0426 - 48ms/epoch - 48ms/step
# Epoch 5/400
# 1/1 - 0s - loss: 0.0226 - val_loss: 0.0424 - 61ms/epoch - 61ms/step
# Epoch 6/400
# 1/1 - 0s - loss: 0.0222 - val_loss: 0.0423 - 74ms/epoch - 74ms/step
# Epoch 7/400
# 1/1 - 0s - loss: 0.0220 - val_loss: 0.0423 - 50ms/epoch - 50ms/step
# Epoch 8/400
# 1/1 - 0s - loss: 0.0217 - val_loss: 0.0424 - 57ms/epoch - 57ms/step
# Epoch 9/400
# 1/1 - 0s - loss: 0.0216 - val_loss: 0.0424 - 51ms/epoch - 51ms/step
# Epoch 10/400
# 1/1 - 0s - loss: 0.0214 - val_loss: 0.0425 - 51ms/epoch - 51ms/step
# Epoch 11/400
# 1/1 - 0s - loss: 0.0213 - val_loss: 0.0425 - 53ms/epoch - 53ms/step
# Saving model.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-7dac52bc513a> in <module>
#      94   history = model.fit(input_, target_, epochs=400, batch_size=32, validation_data=(X_val, y_val), callbacks=[early_stopping], verbose=2)
#      95   print('Saving model.')
# ---> 96   model.save('/content/drive/MyDrive/Colab_Models/RBSeq2Seq')
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/training.py in save(self, filepath, overwrite, include_optimizer, save_format, signatures, options, save_traces)
#    2793         """
#    2794
# -> 2795         save.save_model(
#    2796             self,
#    2797             filepath,
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.8/dist-packages/keras/saving/legacy/save.py in save_model(model, filepath, overwrite, include_optimizer, save_format, signatures, options, save_traces)
#     165     else:
#     166         with serialization.SharedObjectSavingScope():
# --> 167             saved_model_save.save(
#     168                 model,
#     169                 filepath,
#
# /usr/local/lib/python3.8/dist-packages/keras/saving/legacy/saved_model/save.py in save(model, filepath, overwrite, include_optimizer, signatures, options, save_traces)
#      95     with backend.deprecated_internal_learning_phase_scope(0):
#      96         with utils.keras_option_scope(save_traces):
# ---> 97             saved_nodes, node_paths = save_lib.save_and_return_nodes(
#      98                 model, filepath, signatures, options
#      99             )
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/saved_model/save.py in save_and_return_nodes(obj, export_dir, signatures, options, experimental_skip_checkpoint)
#    1265
#    1266   _, exported_graph, object_saver, asset_info, saved_nodes, node_paths = (
# -> 1267       _build_meta_graph(obj, signatures, options, meta_graph_def))
#    1268   saved_model.saved_model_schema_version = (
#    1269       constants.SAVED_MODEL_SCHEMA_VERSION)
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/saved_model/save.py in _build_meta_graph(obj, signatures, options, meta_graph_def)
#    1438
#    1439   with save_context.save_context(options):
# -> 1440     return _build_meta_graph_impl(obj, signatures, options, meta_graph_def)
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/saved_model/save.py in _build_meta_graph_impl(obj, signatures, options, meta_graph_def)
#    1391
#    1392   # Use _SaveableView to provide a frozen listing of properties and functions.
# -> 1393   saveable_view = _SaveableView(augmented_graph_view, options)
#    1394   object_saver = checkpoint.TrackableSaver(augmented_graph_view)
#    1395   asset_info, exported_graph = _fill_meta_graph_def(
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/saved_model/save.py in __init__(self, augmented_graph_view, options)
#     264     (self._trackable_objects, self.node_paths, self.node_ids,
#     265      self._slot_variables, self.object_names) = (
# --> 266          checkpoint_util.objects_ids_and_slot_variables_and_paths(
#     267              self.augmented_graph_view))
#     268
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/checkpoint/util.py in objects_ids_and_slot_variables_and_paths(graph_view)
#     157                 object -> node id, slot variables, object_names)
#     158   """
# --> 159   trackable_objects, node_paths = graph_view.breadth_first_traversal()
#     160   object_names = object_identity.ObjectIdentityDictionary()
#     161   for obj, path in node_paths.items():
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/checkpoint/graph_view.py in breadth_first_traversal(self)
#     122
#     123   def breadth_first_traversal(self):
# --> 124     return self._breadth_first_traversal()
#     125
#     126   def _breadth_first_traversal(self):
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/saved_model/save.py in _breadth_first_traversal(self)
#     141
#     142     trackable_objects, _ = (
# --> 143         super(_AugmentedGraphView, self)._breadth_first_traversal())
#     144
#     145     asset_paths = object_identity.ObjectIdentityDictionary()
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/checkpoint/graph_view.py in _breadth_first_traversal(self)
#     126   def _breadth_first_traversal(self):
#     127     """Find shortest paths to all dependencies of self.root."""
# --> 128     return super(ObjectGraphView, self)._descendants_with_paths()
#     129
#     130   def serialize_object_graph(self, saveables_cache=None):
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/checkpoint/trackable_view.py in _descendants_with_paths(self)
#     109       current_trackable = to_visit.popleft()
#     110       bfs_sorted.append(current_trackable)
# --> 111       for name, dependency in self.children(current_trackable).items():
#     112         if dependency not in node_paths:
#     113           node_paths[dependency] = (
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/checkpoint/graph_view.py in children(self, obj, save_type, **kwargs)
#      95     """
#      96     children = {}
# ---> 97     for name, ref in self.list_children(obj, **kwargs):
#      98       children[name] = ref
#      99     return children
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/saved_model/save.py in list_children(self, obj)
#     175       children = self._children_cache[obj] = {}
#     176
# --> 177       for name, child in super(_AugmentedGraphView, self).list_children(
#     178           obj,
#     179           save_type=base.SaveType.SAVEDMODEL,
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/checkpoint/graph_view.py in list_children(self, obj, save_type, **kwargs)
#      73     """
#      74     children = []
# ---> 75     for name, ref in super(ObjectGraphView,
#      76                            self).children(obj, save_type, **kwargs).items():
#      77       children.append(base.TrackableReference(name, ref))
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/checkpoint/trackable_view.py in children(cls, obj, save_type, **kwargs)
#      82     obj._maybe_initialize_trackable()
#      83     children = {}
# ---> 84     for name, ref in obj._trackable_children(save_type, **kwargs).items():
#      85       ref = converter.convert_to_trackable(ref, parent=obj)
#      86       children[name] = ref
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/trackable/autotrackable.py in _trackable_children(self, save_type, **kwargs)
#     113     for fn in functions.values():
#     114       if isinstance(fn, core_types.GenericFunction):
# --> 115         fn._list_all_concrete_functions_for_serialization()  # pylint: disable=protected-access
#     116
#     117     # Additional dependencies may have been generated during function tracing
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _list_all_concrete_functions_for_serialization(self)
#    1158     concrete_functions = []
#    1159     for args, kwargs in seen_signatures:
# -> 1160       concrete_functions.append(self.get_concrete_function(*args, **kwargs))
#    1161     return concrete_functions
#    1162
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in get_concrete_function(self, *args, **kwargs)
#    1213   def get_concrete_function(self, *args, **kwargs):
#    1214     # Implements GenericFunction.get_concrete_function.
# -> 1215     concrete = self._get_concrete_function_garbage_collected(*args, **kwargs)
#    1216     concrete._garbage_collector.release()  # pylint: disable=protected-access
#    1217     return concrete
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    1204       # In this case we have not created variables on the first call. So we can
#    1205       # run the first trace but we should fail if variables are created.
# -> 1206       concrete = self._variable_creation_fn._get_concrete_function_garbage_collected(  # pylint: disable=protected-access
#    1207           *args, **kwargs)
#    1208       if self._created_variables:
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#     190
#     191     with self._lock:
# --> 192       concrete_function, _ = self._maybe_define_concrete_function(args, kwargs)
#     193       seen_names = set()
#     194       captured = object_identity.ObjectIdentitySet(
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in _maybe_define_concrete_function(self, args, kwargs)
#     155       kwargs = {}
#     156
# --> 157     return self._maybe_define_function(args, kwargs)
#     158
#     159   def _get_concrete_function_internal_garbage_collected(self, *args, **kwargs):
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in _maybe_define_function(self, args, kwargs)
#     358             args, kwargs = generalized_func_key._placeholder_value()  # pylint: disable=protected-access
#     359
# --> 360           concrete_function = self._create_concrete_function(args, kwargs)
#     361
#     362           graph_capture_container = concrete_function.graph._capture_func_lib  # pylint: disable=protected-access
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in _create_concrete_function(self, args, kwargs)
#     282     arg_names = base_arg_names + missing_arg_names
#     283     concrete_function = monomorphic_function.ConcreteFunction(
# --> 284         func_graph_module.func_graph_from_py_func(
#     285             self._name,
#     286             self._python_function,
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, acd_record_initial_resource_uses)
#    1286       # TensorArrays and `None`s.
#    1287       func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
# -> 1288       func_outputs = nest.map_structure(
#    1289           convert, func_outputs, expand_composites=True)
#    1290
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     915
#     916   return pack_sequence_as(
# --> 917       structure[0], [func(*x) for x in entries],
#     918       expand_composites=expand_composites)
#     919
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     915
#     916   return pack_sequence_as(
# --> 917       structure[0], [func(*x) for x in entries],
#     918       expand_composites=expand_composites)
#     919
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/func_graph.py in convert(x)
#    1244               "ExtensionType.")
#    1245       if add_control_dependencies:
# -> 1246         x = deps_ctx.mark_as_return(x)
#    1247       return x
#    1248
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/auto_control_deps.py in mark_as_return(self, tensor)
#     247     # of a new identity operation that the stateful operations definitely don't
#     248     # depend on.
# --> 249     tensor = array_ops.identity(tensor)
#     250     self._returned_tensors.add(tensor)
#     251     return tensor
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1174       # Fallback dispatch system (dispatch v1):
#    1175       try:
# -> 1176         return dispatch_target(*args, **kwargs)
#    1177       except (TypeError, ValueError):
#    1178         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/array_ops.py in identity(input, name)
#     292     # variables. Variables have correct handle data when graph building.
#     293     input = ops.convert_to_tensor(input)
# --> 294   ret = gen_array_ops.identity(input, name=name)
#     295   # Propagate handle data for happier shape inference for resource variables.
#     296   if hasattr(input, "_handle_data"):
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/gen_array_ops.py in identity(input, name)
#    4080       pass  # Add nodes to the TensorFlow graph.
#    4081   # Add nodes to the TensorFlow graph.
# -> 4082   _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    4083         "Identity", input=input, name=name)
#    4084   _result = _outputs[:]
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     793       # Add Op to graph
#     794       # pylint: disable=protected-access
# --> 795       op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#     796                                  name=scope, input_types=input_types,
#     797                                  attrs=attr_protos, op_def=op_def)
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/func_graph.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     747       inp = self.capture(inp)
#     748       captured_inputs.append(inp)
# --> 749     return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     750         op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     751         compute_device)
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3796     # Session.run call cannot occur between creating and mutating the op.
#    3797     with self._mutation_lock():
# -> 3798       ret = Operation(
#    3799           node_def,
#    3800           self,
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py in __init__(***failed resolving arguments***)
#    2104
#    2105     # Initialize c_op from node_def and other inputs
# -> 2106     c_op = _create_c_op(g, node_def, inputs, control_input_ops, op_def=op_def)
#    2107     self._init_from_c_op(c_op=c_op, g=g)
#    2108
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py in _create_c_op(graph, node_def, inputs, control_inputs, op_def, extract_traceback)
#    1954
#    1955   # Add attrs
# -> 1956   for name, attr_value in node_def.attr.items():
#    1957     serialized = attr_value.SerializeToString()
#    1958     # TODO(skyewm): this creates and deletes a new TF_Status for every attr.
#
# /usr/lib/python3.8/_collections_abc.py in __iter__(self)
#     741
#     742     def __iter__(self):
# --> 743         for key in self._mapping:
#     744             yield (key, self._mapping[key])
#     745
#
# KeyboardInterrupt:

# %%
pred = model.predict(input_)
# Out:
# 1/1 [==============================] - 1s 575ms/step

# %%
pred[0][0]
# Out:
# array([ 0.000132,  0.050394,  0.000134,  0.105545,  0.199388, -0.998259,
#         0.996217,  0.374753, -0.996707,  0.993591,  0.250021,  0.999017],
#       dtype=float32)

# %%
target_[0][0]
# Out:
# array([ 0.      ,  0.050601,  0.      ,  0.106061,  0.2     , -0.998046,
#         0.99667 ,  0.375   , -0.99671 ,  0.993647,  0.25    ,  1.      ])

# %%
# Plot history (also known as a loss curve)
import matplotlib.pyplot as plt
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs");

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity

def plot_vectors_cosine_similarity(vector1, vector2):
    similarity = cosine_similarity([vector1], [vector2])[0][0]
    fig, ax = plt.subplots()
    ax.plot(vector1, label='Prediction')
    ax.plot(vector2, label='Target')
    ax.set_title('Cosine Similarity: {:.2f}'.format(similarity))
    ax.legend()
    plt.show()
index = 1
plot_vectors_cosine_similarity(pred[0][index], target_[0][index])

# %%
def comparison_ordering(master, slave):
  """ Compares and orders the inputs by the preds """

  max_finder = pd.DataFrame(columns=["pred", "original_input", "cos_similarity"])
  ordered_rides = pd.DataFrame(columns = [
    'space_type',
    'billable_distance',
    'run_name',
    'rider.mediroutes_rider_id',
    'pickup.event_location.zip',
    'pickup.event_location.longitude',
    'pickup.event_location.latitude',
    'dropoff.event_location.zip',
    'dropoff.event_location.longitude',
    'dropoff.event_location.latitude',
    'pickup_hour',
    'pickup_minute',
    'prediction_highest_scores',
    'similarity_high_score'
  ])

  for i in master: # order the j vector by the master
    for j in slave:
      cos_similarity = cosine_similarity(i.reshape(1, -1), j.reshape(1, -1))

      # Add mapping to max finder
      row = {"pred": i, "original_input": j, "cos_similarity": cos_similarity}
      max_finder = max_finder.append(row, ignore_index=True)

    # Find the winner
    max_row_index = np.argmax(max_finder['cos_similarity'])
    most_similar = max_finder.loc[max_row_index]

    # Get prediction info - just a check to see if max_row_index is returning the best value every time.
    max_finder.sort_values(by='cos_similarity', ascending=False, inplace=True)
    scores = max_finder['cos_similarity'][:3]
    scores = [round(x[0][0],4) for x in scores]

    highest_score = np.amax(scores)
    prediction_info = [np.sort(scores), highest_score]

    # Add most similar ride to ordered rides in order of predictions against the target
    row = {'space_type' : most_similar[1][0],
    'billable_distance' : most_similar[1][1],
    'run_name' : most_similar[1][2],
    'rider.mediroutes_rider_id' : most_similar[1][3],
    'pickup.event_location.zip' : most_similar[1][4],
    'pickup.event_location.longitude' : most_similar[1][5],
    'pickup.event_location.latitude' : most_similar[1][6],
    'dropoff.event_location.zip' : most_similar[1][7],
    'dropoff.event_location.longitude' : most_similar[1][8],
    'dropoff.event_location.latitude' : most_similar[1][9],
    'pickup_hour' : most_similar[1][10],
    'pickup_minute' : most_similar[1][11],
    'prediction_highest_scores' : prediction_info[:-1],
    'similarity_high_score' : prediction_info[1]
    }
    
    ordered_rides = ordered_rides.append(row, ignore_index=True)

    # Reset max finder so it starts empty for the next iteration
    max_finder = pd.DataFrame(columns=["pred", "original_input", "cos_similarity"])
    scores = []
  return ordered_rides

ordered_rides = comparison_ordering(pred[0], input_[0])

# %%
ordered_rides.iloc[:10,:]
# Out:
#    space_type  billable_distance  run_name  rider.mediroutes_rider_id  \
# 0    0.000000           0.050601       0.0                   0.106061
# 1    0.333333           0.016161       0.0                   0.242424
# 2    1.000000           0.003702       0.0                   0.530303
# 3    1.000000           0.012015       0.0                   0.439394
# 4    1.000000           0.002170       0.0                   0.303030
# 5    1.000000           0.013620       0.0                   0.681818
# 6    1.000000           0.013620       0.0                   0.393939
# 7    1.000000           0.013107       0.0                   0.818182
# 8    1.000000           0.014106       0.0                   0.500000
# 9    1.000000           0.014342       0.0                   0.757576
#
#    pickup.event_location.zip  pickup.event_location.longitude  \
# 0                   0.200000                        -0.998046
# 1                   0.833333                        -0.996126
# 2                   0.900000                        -0.996556
# 3                   0.866667                        -0.996193
# 4                   0.600000                        -0.996490
# 5                   0.533333                        -0.995742
# 6                   0.533333                        -0.995742
# 7                   0.533333                        -0.995785
# 8                   0.666667                        -0.995212
# 9                   0.566667                        -0.995512
#
#    pickup.event_location.latitude  dropoff.event_location.zip  \
# 0                        0.996670                     0.37500
# 1                        0.992759                     0.28125
# 2                        0.993023                     0.84375
# 3                        0.992977                     0.71875
# 4                        0.993263                     0.59375
# 5                        0.993810                     0.62500
# 6                        0.993810                     0.62500
# 7                        0.993697                     0.50000
# 8                        0.992815                     0.50000
# 9                        0.994284                     0.65625
#
#    dropoff.event_location.longitude  dropoff.event_location.latitude  \
# 0                         -0.996710                         0.993647
# 1                         -0.996352                         0.991501
# 2                         -0.996582                         0.993274
# 3                         -0.995865                         0.993063
# 4                         -0.996582                         0.993275
# 5                         -0.995342                         0.993172
# 6                         -0.995342                         0.993172
# 7                         -0.995512                         0.994284
# 8                         -0.995539                         0.993897
# 9                         -0.995569                         0.993345
#
#    pickup_hour  pickup_minute prediction_highest_scores  similarity_high_score
# 0     0.250000       1.000000   [[0.8883, 0.9535, 1.0]]                    1.0
# 1     0.333333       1.000000   [[0.9526, 0.9536, 1.0]]                    1.0
# 2     0.416667       0.333333   [[0.9864, 0.9903, 1.0]]                    1.0
# 3     0.416667       0.666667   [[0.9856, 0.9904, 1.0]]                    1.0
# 4     0.500000       0.333333   [[0.9865, 0.9893, 1.0]]                    1.0
# 5     0.583333       0.000000   [[0.9939, 0.9969, 1.0]]                    1.0
# 6     0.583333       0.000000   [[0.9892, 0.9937, 1.0]]                    1.0
# 7     0.666667       0.000000   [[0.9905, 0.9969, 1.0]]                    1.0
# 8     0.666667       1.000000   [[0.9654, 0.9819, 1.0]]                    1.0
# 9     0.750000       0.333333   [[0.9895, 0.9898, 1.0]]                    1.0

# %%
target_df.iloc[:10,:]
# Out:
#    target_space_type  target_billable_distance  target_run_name  \
# 0           0.000000                  0.050601              0.0
# 1           0.333333                  0.016161              0.0
# 2           1.000000                  0.003702              0.0
# 3           1.000000                  0.012015              0.0
# 4           1.000000                  0.002170              0.0
# 5           1.000000                  0.013620              0.0
# 6           1.000000                  0.013620              0.0
# 7           1.000000                  0.013107              0.0
# 8           1.000000                  0.014106              0.0
# 9           1.000000                  0.014342              0.0
#
#    target_rider.mediroutes_rider_id  target_pickup.event_location.zip  \
# 0                          0.106061                          0.200000
# 1                          0.242424                          0.833333
# 2                          0.530303                          0.900000
# 3                          0.439394                          0.866667
# 4                          0.303030                          0.600000
# 5                          0.681818                          0.533333
# 6                          0.393939                          0.533333
# 7                          0.818182                          0.533333
# 8                          0.500000                          0.666667
# 9                          0.757576                          0.566667
#
#    target_pickup.event_location.longitude  \
# 0                               -0.998046
# 1                               -0.996126
# 2                               -0.996556
# 3                               -0.996193
# 4                               -0.996490
# 5                               -0.995742
# 6                               -0.995742
# 7                               -0.995785
# 8                               -0.995212
# 9                               -0.995512
#
#    target_pickup.event_location.latitude  target_dropoff.event_location.zip  \
# 0                               0.996670                            0.37500
# 1                               0.992759                            0.28125
# 2                               0.993023                            0.84375
# 3                               0.992977                            0.71875
# 4                               0.993263                            0.59375
# 5                               0.993810                            0.62500
# 6                               0.993810                            0.62500
# 7                               0.993697                            0.50000
# 8                               0.992815                            0.50000
# 9                               0.994284                            0.65625
#
#    target_dropoff.event_location.longitude  \
# 0                                -0.996710
# 1                                -0.996352
# 2                                -0.996582
# 3                                -0.995865
# 4                                -0.996582
# 5                                -0.995342
# 6                                -0.995342
# 7                                -0.995512
# 8                                -0.995539
# 9                                -0.995569
#
#    target_dropoff.event_location.latitude  target_pickup_hour  \
# 0                                0.993647            0.250000
# 1                                0.991501            0.333333
# 2                                0.993274            0.416667
# 3                                0.993063            0.416667
# 4                                0.993275            0.500000
# 5                                0.993172            0.583333
# 6                                0.993172            0.583333
# 7                                0.994284            0.666667
# 8                                0.993897            0.666667
# 9                                0.993345            0.750000
#
#    target_pickup_minute
# 0              1.000000
# 1              1.000000
# 2              0.333333
# 3              0.666667
# 4              0.333333
# 5              0.000000
# 6              0.000000
# 7              0.000000
# 8              1.000000
# 9              0.333333

# %%
target_df = pd.DataFrame(target[0], columns=[
  'space_type',
  'billable_distance',
  'run_name',
  'rider.mediroutes_rider_id',
  'pickup.event_location.zip',
  'pickup.event_location.longitude',
  'pickup.event_location.latitude',
  'dropoff.event_location.zip',
  'dropoff.event_location.longitude',
  'dropoff.event_location.latitude',
  'pickup_hour',
  'pickup_minute'
])

# %%
target_df.head(10)
