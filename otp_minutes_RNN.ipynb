# %% [markdown]
# <a href="https://colab.research.google.com/github/GarettGazay/ai_projects/blob/master/otp_minutes_RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import required libraries
import tensorflow as tf
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/2022_otp_runs.csv')

# %%
# df = df.drop(['pickup_month', 'pickup_day', 'median_pickup_time_hour'],axis=1)

# %%
df.head()
# Out:
#    pickup_day  pickup_lng  pickup_lat  median_pickup_time_hour  \
# 0    0.008125   -0.989852    0.847646                 0.333333
# 1    0.008125   -0.990825    0.848788                 0.166667
# 2    0.008125   -0.990922    0.846670                 0.208333
# 3    0.008125   -0.990800    0.846893                 0.208333
# 4    0.008125   -0.989395    0.845235                 0.458333
#
#    median_pickup_time_minute  median_dropoff_time_hour  \
# 0                   0.366667                  0.333333
# 1                   0.383333                  0.166667
# 2                   0.050000                  0.208333
# 3                   0.216667                  0.208333
# 4                   0.133333                  0.458333
#
#    median_dropoff_time_minute  dropoff_lng  dropoff_lat  start_dropoff_lng  \
# 0                    0.733333    -0.989807     0.302661          -0.989852
# 1                    0.800000    -0.990424     0.303688          -0.990825
# 2                    0.516667    -0.990674     0.303178          -0.990424
# 3                    0.483333    -0.990674     0.303178          -0.990674
# 4                    0.766667    -0.990521     0.303068          -0.989395
#
#    start_dropoff_lat  start_median_dropoff_time_hour  \
# 0           0.303341                        0.333333
# 1           0.303750                        0.166667
# 2           0.303688                        0.166667
# 3           0.303178                        0.208333
# 4           0.302478                        0.458333
#
#    start_median_dropoff_time_minute  billable_distance
# 0                          0.366667           0.088237
# 1                          0.383333           0.057734
# 2                          0.800000           0.029978
# 3                          0.516667           0.017937
# 4                          0.133333           0.109662

# %%
# Create train and test splits the right way for time series data
split_size = int(0.8 * len(df)) # 80% train, 20% test
split_size
# Out:
# 21879

# %%
X_minute = df

# %%
y_minute = X_minute["median_pickup_time_minute"]
X_minute = X_minute.drop(['median_pickup_time_minute'], axis=1)

# %%
# Create train data splits (everything before the split)
X_train, y_train = X_minute[:split_size], y_minute[:split_size]

# %%
y_train.head(25)
# Out:
# 0     0.366667
# 1     0.383333
# 2     0.050000
# 3     0.216667
# 4     0.133333
# 5     0.716667
# 6     0.983333
# 7     0.850000
# 8     0.966667
# 9     0.333333
# 10    0.033333
# 11    0.050000
# 12    0.933333
# 13    0.366667
# 14    0.016667
# 15    0.950000
# 16    0.933333
# 17    0.566667
# 18    0.966667
# 19    0.783333
# 20    0.616667
# 21    0.716667
# 22    0.033333
# 23    0.866667
# 24    0.316667
# Name: median_pickup_time_minute, dtype: float64

# %%
# Create test data splits (everything after the split)
X_test, y_test = X_minute[split_size:], y_minute[split_size:]

# %%
X_train = X_train.astype('float32')
y_train = y_train.astype('float32')
X_test = X_test.astype('float32')
y_test = y_test.astype('float32')

# X_train.dtypes, y_train.dtypes, X_test.dtypes, y_test.dtypes

# %%
X_train.head()
# Out:
#    pickup_day  pickup_lng  pickup_lat  median_pickup_time_hour  \
# 0    0.008125   -0.989852    0.847646                 0.333333
# 1    0.008125   -0.990825    0.848788                 0.166667
# 2    0.008125   -0.990922    0.846670                 0.208333
# 3    0.008125   -0.990800    0.846893                 0.208333
# 4    0.008125   -0.989395    0.845235                 0.458333
#
#    median_dropoff_time_hour  median_dropoff_time_minute  dropoff_lng  \
# 0                  0.333333                    0.733333    -0.989807
# 1                  0.166667                    0.800000    -0.990424
# 2                  0.208333                    0.516667    -0.990674
# 3                  0.208333                    0.483333    -0.990674
# 4                  0.458333                    0.766667    -0.990521
#
#    dropoff_lat  start_dropoff_lng  start_dropoff_lat  \
# 0     0.302661          -0.989852           0.303341
# 1     0.303688          -0.990825           0.303750
# 2     0.303178          -0.990424           0.303688
# 3     0.303178          -0.990674           0.303178
# 4     0.303068          -0.989395           0.302478
#
#    start_median_dropoff_time_hour  start_median_dropoff_time_minute  \
# 0                        0.333333                          0.366667
# 1                        0.166667                          0.383333
# 2                        0.166667                          0.800000
# 3                        0.208333                          0.516667
# 4                        0.458333                          0.133333
#
#    billable_distance
# 0           0.088237
# 1           0.057734
# 2           0.029978
# 3           0.017937
# 4           0.109662

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='mae', patience=5)

# %%
X_train.shape
# Out:
# (21879, 13)

# %%
# Create a new model (same as model_2)
# minute_model = tf.keras.Sequential([
#   tf.keras.layers.Dense(34, activation='relu'),
#   tf.keras.layers.Dense(34, activation='relu'),
#   tf.keras.layers.Dense(16, activation='relu'),
#   tf.keras.layers.Dense(1)
# ])

# # Compile the model
# minute_model.compile(loss=tf.keras.losses.mae,
#                 optimizer=tf.keras.optimizers.Adam(),
#                 metrics=['mae'],
#                 )

# history = minute_model.fit(
#     X_train,
#     y_train,
#     epochs=500,
#     batch_size=32,
#     validation_split=0.1,
#     verbose=2,
#     callbacks=[early_stopping]
#     )

X_train = X_train.values.reshape(X_train.shape[0], 1, X_train.shape[1])
# Create a new model
minute_model = tf.keras.Sequential([
  tf.keras.layers.LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
  tf.keras.layers.LSTM(25),
  tf.keras.layers.Dense(1)
])

# Compile the model
minute_model.compile(loss=tf.keras.losses.mae,
                optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
                metrics=['mae'],
                )

history = minute_model.fit(
    X_train,
    y_train,
    epochs=500,
    batch_size=32,
    validation_split=0.1,
    verbose=2,
    callbacks=[early_stopping]
    )
# Out:
# Epoch 1/500
# 616/616 - 21s - loss: 0.3109 - mae: 0.3109 - val_loss: 0.2511 - val_mae: 0.2511 - 21s/epoch - 33ms/step
# Epoch 2/500
# 616/616 - 3s - loss: 0.2550 - mae: 0.2550 - val_loss: 0.2478 - val_mae: 0.2478 - 3s/epoch - 4ms/step
# Epoch 3/500
# 616/616 - 3s - loss: 0.2522 - mae: 0.2522 - val_loss: 0.2446 - val_mae: 0.2446 - 3s/epoch - 4ms/step
# Epoch 4/500
# 616/616 - 3s - loss: 0.2496 - mae: 0.2496 - val_loss: 0.2421 - val_mae: 0.2421 - 3s/epoch - 4ms/step
# Epoch 5/500
# 616/616 - 3s - loss: 0.2472 - mae: 0.2472 - val_loss: 0.2396 - val_mae: 0.2396 - 3s/epoch - 4ms/step
# Epoch 6/500
# 616/616 - 3s - loss: 0.2451 - mae: 0.2451 - val_loss: 0.2381 - val_mae: 0.2381 - 3s/epoch - 5ms/step
# Epoch 7/500
# 616/616 - 3s - loss: 0.2434 - mae: 0.2434 - val_loss: 0.2358 - val_mae: 0.2358 - 3s/epoch - 4ms/step
# Epoch 8/500
# 616/616 - 3s - loss: 0.2416 - mae: 0.2416 - val_loss: 0.2338 - val_mae: 0.2338 - 3s/epoch - 4ms/step
# Epoch 9/500
# 616/616 - 3s - loss: 0.2396 - mae: 0.2396 - val_loss: 0.2322 - val_mae: 0.2322 - 3s/epoch - 4ms/step
# Epoch 10/500
# 616/616 - 3s - loss: 0.2375 - mae: 0.2375 - val_loss: 0.2291 - val_mae: 0.2291 - 3s/epoch - 4ms/step
# Epoch 11/500
# 616/616 - 3s - loss: 0.2348 - mae: 0.2348 - val_loss: 0.2255 - val_mae: 0.2255 - 3s/epoch - 5ms/step
# Epoch 12/500
# 616/616 - 3s - loss: 0.2317 - mae: 0.2317 - val_loss: 0.2213 - val_mae: 0.2213 - 3s/epoch - 4ms/step
# Epoch 13/500
# 616/616 - 3s - loss: 0.2278 - mae: 0.2278 - val_loss: 0.2180 - val_mae: 0.2180 - 3s/epoch - 4ms/step
# Epoch 14/500
# 616/616 - 3s - loss: 0.2235 - mae: 0.2235 - val_loss: 0.2117 - val_mae: 0.2117 - 3s/epoch - 4ms/step
# Epoch 15/500
# 616/616 - 3s - loss: 0.2186 - mae: 0.2186 - val_loss: 0.2051 - val_mae: 0.2051 - 3s/epoch - 4ms/step
# Epoch 16/500
# 616/616 - 3s - loss: 0.2140 - mae: 0.2140 - val_loss: 0.2002 - val_mae: 0.2002 - 3s/epoch - 4ms/step
# Epoch 17/500
# 616/616 - 3s - loss: 0.2112 - mae: 0.2112 - val_loss: 0.1986 - val_mae: 0.1986 - 3s/epoch - 4ms/step
# Epoch 18/500
# 616/616 - 3s - loss: 0.2101 - mae: 0.2101 - val_loss: 0.1981 - val_mae: 0.1981 - 3s/epoch - 4ms/step
# Epoch 19/500
# 616/616 - 3s - loss: 0.2091 - mae: 0.2091 - val_loss: 0.1971 - val_mae: 0.1971 - 3s/epoch - 4ms/step
# Epoch 20/500
# 616/616 - 3s - loss: 0.2084 - mae: 0.2084 - val_loss: 0.1972 - val_mae: 0.1972 - 3s/epoch - 4ms/step
# Epoch 21/500
# 616/616 - 3s - loss: 0.2075 - mae: 0.2075 - val_loss: 0.1957 - val_mae: 0.1957 - 3s/epoch - 4ms/step
# Epoch 22/500
# 616/616 - 3s - loss: 0.2065 - mae: 0.2065 - val_loss: 0.1952 - val_mae: 0.1952 - 3s/epoch - 4ms/step
# Epoch 23/500
# 616/616 - 3s - loss: 0.2056 - mae: 0.2056 - val_loss: 0.1946 - val_mae: 0.1946 - 3s/epoch - 4ms/step
# Epoch 24/500
# 616/616 - 3s - loss: 0.2046 - mae: 0.2046 - val_loss: 0.1935 - val_mae: 0.1935 - 3s/epoch - 4ms/step
# Epoch 25/500
# 616/616 - 3s - loss: 0.2037 - mae: 0.2037 - val_loss: 0.1925 - val_mae: 0.1925 - 3s/epoch - 4ms/step
# Epoch 26/500
# 616/616 - 3s - loss: 0.2025 - mae: 0.2025 - val_loss: 0.1917 - val_mae: 0.1917 - 3s/epoch - 4ms/step
# Epoch 27/500
# 616/616 - 3s - loss: 0.2013 - mae: 0.2013 - val_loss: 0.1905 - val_mae: 0.1905 - 3s/epoch - 4ms/step
# Epoch 28/500
# 616/616 - 3s - loss: 0.2000 - mae: 0.2000 - val_loss: 0.1896 - val_mae: 0.1896 - 3s/epoch - 4ms/step
# Epoch 29/500
# 616/616 - 3s - loss: 0.1987 - mae: 0.1987 - val_loss: 0.1881 - val_mae: 0.1881 - 3s/epoch - 4ms/step
# Epoch 30/500
# 616/616 - 3s - loss: 0.1972 - mae: 0.1972 - val_loss: 0.1869 - val_mae: 0.1869 - 3s/epoch - 5ms/step
# Epoch 31/500
# 616/616 - 3s - loss: 0.1957 - mae: 0.1957 - val_loss: 0.1861 - val_mae: 0.1861 - 3s/epoch - 4ms/step
# Epoch 32/500
# 616/616 - 3s - loss: 0.1942 - mae: 0.1942 - val_loss: 0.1843 - val_mae: 0.1843 - 3s/epoch - 4ms/step
# Epoch 33/500
# 616/616 - 3s - loss: 0.1925 - mae: 0.1925 - val_loss: 0.1824 - val_mae: 0.1824 - 3s/epoch - 5ms/step
# Epoch 34/500
# 616/616 - 3s - loss: 0.1908 - mae: 0.1908 - val_loss: 0.1829 - val_mae: 0.1829 - 3s/epoch - 4ms/step
# Epoch 35/500
# 616/616 - 3s - loss: 0.1888 - mae: 0.1888 - val_loss: 0.1810 - val_mae: 0.1810 - 3s/epoch - 5ms/step
# Epoch 36/500
# 616/616 - 3s - loss: 0.1868 - mae: 0.1868 - val_loss: 0.1770 - val_mae: 0.1770 - 3s/epoch - 4ms/step
# Epoch 37/500
# 616/616 - 3s - loss: 0.1849 - mae: 0.1849 - val_loss: 0.1759 - val_mae: 0.1759 - 3s/epoch - 4ms/step
# Epoch 38/500
# 616/616 - 3s - loss: 0.1826 - mae: 0.1826 - val_loss: 0.1741 - val_mae: 0.1741 - 3s/epoch - 5ms/step
# Epoch 39/500
# 616/616 - 3s - loss: 0.1807 - mae: 0.1807 - val_loss: 0.1719 - val_mae: 0.1719 - 3s/epoch - 4ms/step
# Epoch 40/500
# 616/616 - 3s - loss: 0.1786 - mae: 0.1786 - val_loss: 0.1699 - val_mae: 0.1699 - 3s/epoch - 4ms/step
# Epoch 41/500
# 616/616 - 3s - loss: 0.1765 - mae: 0.1765 - val_loss: 0.1683 - val_mae: 0.1683 - 3s/epoch - 4ms/step
# Epoch 42/500
# 616/616 - 3s - loss: 0.1745 - mae: 0.1745 - val_loss: 0.1711 - val_mae: 0.1711 - 3s/epoch - 4ms/step
# Epoch 43/500
# 616/616 - 3s - loss: 0.1723 - mae: 0.1723 - val_loss: 0.1685 - val_mae: 0.1685 - 3s/epoch - 4ms/step
# Epoch 44/500
# 616/616 - 3s - loss: 0.1709 - mae: 0.1709 - val_loss: 0.1633 - val_mae: 0.1633 - 3s/epoch - 4ms/step
# Epoch 45/500
# 616/616 - 3s - loss: 0.1685 - mae: 0.1685 - val_loss: 0.1623 - val_mae: 0.1623 - 3s/epoch - 4ms/step
# Epoch 46/500
# 616/616 - 3s - loss: 0.1672 - mae: 0.1672 - val_loss: 0.1610 - val_mae: 0.1610 - 3s/epoch - 4ms/step
# Epoch 47/500
# 616/616 - 3s - loss: 0.1653 - mae: 0.1653 - val_loss: 0.1596 - val_mae: 0.1596 - 3s/epoch - 4ms/step
# Epoch 48/500
# 616/616 - 3s - loss: 0.1638 - mae: 0.1638 - val_loss: 0.1590 - val_mae: 0.1590 - 3s/epoch - 4ms/step
# Epoch 49/500
# 616/616 - 3s - loss: 0.1628 - mae: 0.1628 - val_loss: 0.1579 - val_mae: 0.1579 - 3s/epoch - 4ms/step
# Epoch 50/500
# 616/616 - 3s - loss: 0.1619 - mae: 0.1619 - val_loss: 0.1569 - val_mae: 0.1569 - 3s/epoch - 4ms/step
# Epoch 51/500
# 616/616 - 3s - loss: 0.1603 - mae: 0.1603 - val_loss: 0.1568 - val_mae: 0.1568 - 3s/epoch - 4ms/step
# Epoch 52/500
# 616/616 - 3s - loss: 0.1596 - mae: 0.1596 - val_loss: 0.1565 - val_mae: 0.1565 - 3s/epoch - 4ms/step
# Epoch 53/500
# 616/616 - 3s - loss: 0.1584 - mae: 0.1584 - val_loss: 0.1609 - val_mae: 0.1609 - 3s/epoch - 4ms/step
# Epoch 54/500
# 616/616 - 3s - loss: 0.1581 - mae: 0.1581 - val_loss: 0.1564 - val_mae: 0.1564 - 3s/epoch - 4ms/step
# Epoch 55/500
# 616/616 - 3s - loss: 0.1575 - mae: 0.1575 - val_loss: 0.1571 - val_mae: 0.1571 - 3s/epoch - 4ms/step
# Epoch 56/500
# 616/616 - 3s - loss: 0.1568 - mae: 0.1568 - val_loss: 0.1560 - val_mae: 0.1560 - 3s/epoch - 4ms/step
# Epoch 57/500
# 616/616 - 3s - loss: 0.1561 - mae: 0.1561 - val_loss: 0.1561 - val_mae: 0.1561 - 3s/epoch - 4ms/step
# Epoch 58/500
# 616/616 - 3s - loss: 0.1554 - mae: 0.1554 - val_loss: 0.1534 - val_mae: 0.1534 - 3s/epoch - 4ms/step
# Epoch 59/500
# 616/616 - 3s - loss: 0.1551 - mae: 0.1551 - val_loss: 0.1531 - val_mae: 0.1531 - 3s/epoch - 4ms/step
# Epoch 60/500
# 616/616 - 3s - loss: 0.1543 - mae: 0.1543 - val_loss: 0.1560 - val_mae: 0.1560 - 3s/epoch - 4ms/step
# Epoch 61/500
# 616/616 - 3s - loss: 0.1541 - mae: 0.1541 - val_loss: 0.1535 - val_mae: 0.1535 - 3s/epoch - 5ms/step
# Epoch 62/500
# 616/616 - 3s - loss: 0.1536 - mae: 0.1536 - val_loss: 0.1531 - val_mae: 0.1531 - 3s/epoch - 4ms/step
# Epoch 63/500
# 616/616 - 3s - loss: 0.1537 - mae: 0.1537 - val_loss: 0.1523 - val_mae: 0.1523 - 3s/epoch - 4ms/step
# Epoch 64/500
# 616/616 - 3s - loss: 0.1528 - mae: 0.1528 - val_loss: 0.1525 - val_mae: 0.1525 - 3s/epoch - 5ms/step
# Epoch 65/500
# 616/616 - 3s - loss: 0.1526 - mae: 0.1526 - val_loss: 0.1547 - val_mae: 0.1547 - 3s/epoch - 4ms/step
# Epoch 66/500
# 616/616 - 3s - loss: 0.1522 - mae: 0.1522 - val_loss: 0.1516 - val_mae: 0.1516 - 3s/epoch - 4ms/step
# Epoch 67/500
# 616/616 - 3s - loss: 0.1523 - mae: 0.1523 - val_loss: 0.1522 - val_mae: 0.1522 - 3s/epoch - 4ms/step
# Epoch 68/500
# 616/616 - 3s - loss: 0.1517 - mae: 0.1517 - val_loss: 0.1600 - val_mae: 0.1600 - 3s/epoch - 4ms/step
# Epoch 69/500
# 616/616 - 3s - loss: 0.1518 - mae: 0.1518 - val_loss: 0.1507 - val_mae: 0.1507 - 3s/epoch - 4ms/step
# Epoch 70/500
# 616/616 - 3s - loss: 0.1510 - mae: 0.1510 - val_loss: 0.1513 - val_mae: 0.1513 - 3s/epoch - 4ms/step
# Epoch 71/500
# 616/616 - 3s - loss: 0.1510 - mae: 0.1510 - val_loss: 0.1519 - val_mae: 0.1519 - 3s/epoch - 4ms/step
# Epoch 72/500
# 616/616 - 3s - loss: 0.1514 - mae: 0.1514 - val_loss: 0.1543 - val_mae: 0.1543 - 3s/epoch - 4ms/step
# Epoch 73/500
# 616/616 - 3s - loss: 0.1512 - mae: 0.1512 - val_loss: 0.1504 - val_mae: 0.1504 - 3s/epoch - 4ms/step
# Epoch 74/500
# 616/616 - 3s - loss: 0.1503 - mae: 0.1503 - val_loss: 0.1518 - val_mae: 0.1518 - 3s/epoch - 4ms/step
# Epoch 75/500
# 616/616 - 3s - loss: 0.1503 - mae: 0.1503 - val_loss: 0.1498 - val_mae: 0.1498 - 3s/epoch - 4ms/step
# Epoch 76/500
# 616/616 - 3s - loss: 0.1502 - mae: 0.1502 - val_loss: 0.1502 - val_mae: 0.1502 - 3s/epoch - 5ms/step
# Epoch 77/500
# 616/616 - 3s - loss: 0.1499 - mae: 0.1499 - val_loss: 0.1655 - val_mae: 0.1655 - 3s/epoch - 4ms/step
# Epoch 78/500
# 616/616 - 3s - loss: 0.1495 - mae: 0.1495 - val_loss: 0.1517 - val_mae: 0.1517 - 3s/epoch - 4ms/step
# Epoch 79/500
# 616/616 - 3s - loss: 0.1497 - mae: 0.1497 - val_loss: 0.1501 - val_mae: 0.1501 - 3s/epoch - 4ms/step
# Epoch 80/500
# 616/616 - 3s - loss: 0.1492 - mae: 0.1492 - val_loss: 0.1497 - val_mae: 0.1497 - 3s/epoch - 4ms/step
# Epoch 81/500
# 616/616 - 3s - loss: 0.1490 - mae: 0.1490 - val_loss: 0.1495 - val_mae: 0.1495 - 3s/epoch - 4ms/step
# Epoch 82/500
# 616/616 - 3s - loss: 0.1489 - mae: 0.1489 - val_loss: 0.1533 - val_mae: 0.1533 - 3s/epoch - 4ms/step
# Epoch 83/500
# 616/616 - 3s - loss: 0.1491 - mae: 0.1491 - val_loss: 0.1492 - val_mae: 0.1492 - 3s/epoch - 4ms/step
# Epoch 84/500
# 616/616 - 3s - loss: 0.1487 - mae: 0.1487 - val_loss: 0.1546 - val_mae: 0.1546 - 3s/epoch - 4ms/step
# Epoch 85/500
# 616/616 - 3s - loss: 0.1487 - mae: 0.1487 - val_loss: 0.1502 - val_mae: 0.1502 - 3s/epoch - 4ms/step
# Epoch 86/500
# 616/616 - 3s - loss: 0.1482 - mae: 0.1482 - val_loss: 0.1491 - val_mae: 0.1491 - 3s/epoch - 4ms/step
# Epoch 87/500
# 616/616 - 3s - loss: 0.1485 - mae: 0.1485 - val_loss: 0.1511 - val_mae: 0.1511 - 3s/epoch - 4ms/step
# Epoch 88/500
# 616/616 - 3s - loss: 0.1479 - mae: 0.1479 - val_loss: 0.1535 - val_mae: 0.1535 - 3s/epoch - 4ms/step
# Epoch 89/500
# 616/616 - 3s - loss: 0.1482 - mae: 0.1482 - val_loss: 0.1493 - val_mae: 0.1493 - 3s/epoch - 4ms/step
# Epoch 90/500
# 616/616 - 3s - loss: 0.1481 - mae: 0.1481 - val_loss: 0.1527 - val_mae: 0.1527 - 3s/epoch - 4ms/step
# Epoch 91/500
# 616/616 - 3s - loss: 0.1479 - mae: 0.1479 - val_loss: 0.1538 - val_mae: 0.1538 - 3s/epoch - 4ms/step
# Epoch 92/500
# 616/616 - 3s - loss: 0.1478 - mae: 0.1478 - val_loss: 0.1519 - val_mae: 0.1519 - 3s/epoch - 4ms/step
# Epoch 93/500
# 616/616 - 3s - loss: 0.1478 - mae: 0.1478 - val_loss: 0.1506 - val_mae: 0.1506 - 3s/epoch - 4ms/step
# Epoch 94/500
# 616/616 - 3s - loss: 0.1475 - mae: 0.1475 - val_loss: 0.1491 - val_mae: 0.1491 - 3s/epoch - 4ms/step
# Epoch 95/500
# 616/616 - 3s - loss: 0.1474 - mae: 0.1474 - val_loss: 0.1497 - val_mae: 0.1497 - 3s/epoch - 4ms/step
# Epoch 96/500
# 616/616 - 3s - loss: 0.1470 - mae: 0.1470 - val_loss: 0.1525 - val_mae: 0.1525 - 3s/epoch - 4ms/step
# Epoch 97/500
# 616/616 - 3s - loss: 0.1475 - mae: 0.1475 - val_loss: 0.1549 - val_mae: 0.1549 - 3s/epoch - 4ms/step
# Epoch 98/500
# 616/616 - 3s - loss: 0.1471 - mae: 0.1471 - val_loss: 0.1500 - val_mae: 0.1500 - 3s/epoch - 5ms/step
# Epoch 99/500
# 616/616 - 3s - loss: 0.1468 - mae: 0.1468 - val_loss: 0.1509 - val_mae: 0.1509 - 3s/epoch - 4ms/step
# Epoch 100/500
# 616/616 - 3s - loss: 0.1474 - mae: 0.1474 - val_loss: 0.1507 - val_mae: 0.1507 - 3s/epoch - 4ms/step
# Epoch 101/500
# 616/616 - 3s - loss: 0.1471 - mae: 0.1471 - val_loss: 0.1539 - val_mae: 0.1539 - 3s/epoch - 4ms/step
# Epoch 102/500
# 616/616 - 3s - loss: 0.1473 - mae: 0.1473 - val_loss: 0.1494 - val_mae: 0.1494 - 3s/epoch - 4ms/step
# Epoch 103/500
# 616/616 - 3s - loss: 0.1470 - mae: 0.1470 - val_loss: 0.1514 - val_mae: 0.1514 - 3s/epoch - 4ms/step
# Epoch 104/500
# 616/616 - 3s - loss: 0.1467 - mae: 0.1467 - val_loss: 0.1485 - val_mae: 0.1485 - 3s/epoch - 4ms/step
# Epoch 105/500
# 616/616 - 3s - loss: 0.1468 - mae: 0.1468 - val_loss: 0.1488 - val_mae: 0.1488 - 3s/epoch - 5ms/step
# Epoch 106/500
# 616/616 - 3s - loss: 0.1468 - mae: 0.1468 - val_loss: 0.1663 - val_mae: 0.1663 - 3s/epoch - 5ms/step
# Epoch 107/500
# 616/616 - 3s - loss: 0.1467 - mae: 0.1467 - val_loss: 0.1548 - val_mae: 0.1548 - 3s/epoch - 4ms/step
# Epoch 108/500
# 616/616 - 3s - loss: 0.1462 - mae: 0.1462 - val_loss: 0.1545 - val_mae: 0.1545 - 3s/epoch - 4ms/step
# Epoch 109/500
# 616/616 - 3s - loss: 0.1468 - mae: 0.1468 - val_loss: 0.1486 - val_mae: 0.1486 - 3s/epoch - 4ms/step
# Epoch 110/500
# 616/616 - 3s - loss: 0.1464 - mae: 0.1464 - val_loss: 0.1506 - val_mae: 0.1506 - 3s/epoch - 4ms/step
# Epoch 111/500
# 616/616 - 3s - loss: 0.1467 - mae: 0.1467 - val_loss: 0.1502 - val_mae: 0.1502 - 3s/epoch - 4ms/step
# Epoch 112/500
# 616/616 - 3s - loss: 0.1462 - mae: 0.1462 - val_loss: 0.1506 - val_mae: 0.1506 - 3s/epoch - 4ms/step
# Epoch 113/500
# 616/616 - 3s - loss: 0.1462 - mae: 0.1462 - val_loss: 0.1489 - val_mae: 0.1489 - 3s/epoch - 4ms/step
# Epoch 114/500
# 616/616 - 3s - loss: 0.1464 - mae: 0.1464 - val_loss: 0.1496 - val_mae: 0.1496 - 3s/epoch - 4ms/step
# Epoch 115/500
# 616/616 - 3s - loss: 0.1460 - mae: 0.1460 - val_loss: 0.1500 - val_mae: 0.1500 - 3s/epoch - 4ms/step
# Epoch 116/500
# 616/616 - 3s - loss: 0.1462 - mae: 0.1462 - val_loss: 0.1518 - val_mae: 0.1518 - 3s/epoch - 4ms/step
# Epoch 117/500
# 616/616 - 3s - loss: 0.1465 - mae: 0.1465 - val_loss: 0.1488 - val_mae: 0.1488 - 3s/epoch - 4ms/step
# Epoch 118/500
# 616/616 - 3s - loss: 0.1456 - mae: 0.1456 - val_loss: 0.1496 - val_mae: 0.1496 - 3s/epoch - 4ms/step
# Epoch 119/500
# 616/616 - 3s - loss: 0.1459 - mae: 0.1459 - val_loss: 0.1487 - val_mae: 0.1487 - 3s/epoch - 4ms/step
# Epoch 120/500
# 616/616 - 3s - loss: 0.1455 - mae: 0.1455 - val_loss: 0.1481 - val_mae: 0.1481 - 3s/epoch - 4ms/step
# Epoch 121/500
# 616/616 - 3s - loss: 0.1453 - mae: 0.1453 - val_loss: 0.1479 - val_mae: 0.1479 - 3s/epoch - 4ms/step
# Epoch 122/500
# 616/616 - 3s - loss: 0.1454 - mae: 0.1454 - val_loss: 0.1580 - val_mae: 0.1580 - 3s/epoch - 4ms/step
# Epoch 123/500
# 616/616 - 3s - loss: 0.1459 - mae: 0.1459 - val_loss: 0.1520 - val_mae: 0.1520 - 3s/epoch - 4ms/step
# Epoch 124/500
# 616/616 - 3s - loss: 0.1456 - mae: 0.1456 - val_loss: 0.1484 - val_mae: 0.1484 - 3s/epoch - 4ms/step
# Epoch 125/500
# 616/616 - 3s - loss: 0.1463 - mae: 0.1463 - val_loss: 0.1524 - val_mae: 0.1524 - 3s/epoch - 4ms/step
# Epoch 126/500
# 616/616 - 3s - loss: 0.1452 - mae: 0.1452 - val_loss: 0.1563 - val_mae: 0.1563 - 3s/epoch - 4ms/step
# Epoch 127/500
# 616/616 - 3s - loss: 0.1453 - mae: 0.1453 - val_loss: 0.1480 - val_mae: 0.1480 - 3s/epoch - 5ms/step
# Epoch 128/500
# 616/616 - 3s - loss: 0.1458 - mae: 0.1458 - val_loss: 0.1479 - val_mae: 0.1479 - 3s/epoch - 4ms/step
# Epoch 129/500
# 616/616 - 3s - loss: 0.1458 - mae: 0.1458 - val_loss: 0.1538 - val_mae: 0.1538 - 3s/epoch - 5ms/step
# Epoch 130/500
# 616/616 - 3s - loss: 0.1453 - mae: 0.1453 - val_loss: 0.1551 - val_mae: 0.1551 - 3s/epoch - 4ms/step
# Epoch 131/500
# 616/616 - 3s - loss: 0.1451 - mae: 0.1451 - val_loss: 0.1487 - val_mae: 0.1487 - 3s/epoch - 4ms/step
# Epoch 132/500
# 616/616 - 3s - loss: 0.1449 - mae: 0.1449 - val_loss: 0.1480 - val_mae: 0.1480 - 3s/epoch - 4ms/step
# Epoch 133/500
# 616/616 - 3s - loss: 0.1450 - mae: 0.1450 - val_loss: 0.1517 - val_mae: 0.1517 - 3s/epoch - 4ms/step
# Epoch 134/500
# 616/616 - 3s - loss: 0.1450 - mae: 0.1450 - val_loss: 0.1492 - val_mae: 0.1492 - 3s/epoch - 4ms/step
# Epoch 135/500
# 616/616 - 3s - loss: 0.1449 - mae: 0.1449 - val_loss: 0.1482 - val_mae: 0.1482 - 3s/epoch - 4ms/step
# Epoch 136/500
# 616/616 - 3s - loss: 0.1450 - mae: 0.1450 - val_loss: 0.1480 - val_mae: 0.1480 - 3s/epoch - 4ms/step
# Epoch 137/500
# 616/616 - 3s - loss: 0.1453 - mae: 0.1453 - val_loss: 0.1498 - val_mae: 0.1498 - 3s/epoch - 4ms/step
# Epoch 138/500
# 616/616 - 3s - loss: 0.1451 - mae: 0.1451 - val_loss: 0.1526 - val_mae: 0.1526 - 3s/epoch - 4ms/step
# Epoch 139/500
# 616/616 - 3s - loss: 0.1457 - mae: 0.1457 - val_loss: 0.1647 - val_mae: 0.1647 - 3s/epoch - 4ms/step
# Epoch 140/500
# 616/616 - 3s - loss: 0.1447 - mae: 0.1447 - val_loss: 0.1583 - val_mae: 0.1583 - 3s/epoch - 5ms/step
# Epoch 141/500
# 616/616 - 3s - loss: 0.1447 - mae: 0.1447 - val_loss: 0.1475 - val_mae: 0.1475 - 3s/epoch - 5ms/step
# Epoch 142/500
# 616/616 - 3s - loss: 0.1444 - mae: 0.1444 - val_loss: 0.1504 - val_mae: 0.1504 - 3s/epoch - 4ms/step
# Epoch 143/500
# 616/616 - 3s - loss: 0.1448 - mae: 0.1448 - val_loss: 0.1475 - val_mae: 0.1475 - 3s/epoch - 4ms/step
# Epoch 144/500
# 616/616 - 3s - loss: 0.1445 - mae: 0.1445 - val_loss: 0.1489 - val_mae: 0.1489 - 3s/epoch - 5ms/step
# Epoch 145/500
# 616/616 - 3s - loss: 0.1445 - mae: 0.1445 - val_loss: 0.1477 - val_mae: 0.1477 - 3s/epoch - 4ms/step
# Epoch 146/500
# 616/616 - 3s - loss: 0.1449 - mae: 0.1449 - val_loss: 0.1486 - val_mae: 0.1486 - 3s/epoch - 4ms/step
# Epoch 147/500
# 616/616 - 3s - loss: 0.1447 - mae: 0.1447 - val_loss: 0.1695 - val_mae: 0.1695 - 3s/epoch - 4ms/step

# %%
# Plot history (also known as a loss curve)
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs");

# %%
y_pred = minute_model.predict(X_test.values.reshape(X_test.shape[0], 1, X_test.shape[1]))
# Out:
# 171/171 [==============================] - 1s 2ms/step

# %%
result = pd.DataFrame(X_test)

# %%
result['y_pred(minute)'] = y_pred

# %%
result.head()
# Out:
#        pickup_day  pickup_lng  pickup_lat  median_pickup_time_hour  \
# 21879    0.024374   -0.987700    0.841094                 0.333333
# 21880    0.024374   -0.990655    0.847091                 0.375000
# 21881    0.024374   -0.990703    0.847379                 0.416667
# 21882    0.024374   -0.990704    0.847378                 0.416667
# 21883    0.024374   -0.990910    0.845958                 0.500000
#
#        median_dropoff_time_hour  median_dropoff_time_minute  dropoff_lng  \
# 21879                  0.333333                    0.700000     0.302478
# 21880                  0.416667                    0.166667     0.303044
# 21881                  0.416667                    0.900000     0.302669
# 21882                  0.458333                    0.350000     0.303230
# 21883                  0.541667                    0.233333     0.303052
#
#        dropoff_lat  start_dropoff_lng  start_dropoff_lat  \
# 21879    -0.989395          -0.987700           0.300996
# 21880    -0.990834           0.302478          -0.989395
# 21881    -0.990499           0.303044          -0.990834
# 21882    -0.990954           0.302669          -0.990499
# 21883    -0.990221           0.303230          -0.990954
#
#        start_median_dropoff_time_hour  start_median_dropoff_time_minute  \
# 21879                        0.333333                          0.300000
# 21880                        0.333333                          0.700000
# 21881                        0.416667                          0.166667
# 21882                        0.416667                          0.900000
# 21883                        0.458333                          0.350000
#
#        billable_distance  y_pred(minute)
# 21879           0.167669        0.266454
# 21880           0.022274        0.735748
# 21881           0.069765        0.576710
# 21882           0.015135        0.803990
# 21883           0.091094        0.592177

# %%
result = pd.DataFrame([result['start_median_dropoff_time_minute'], result['y_pred(minute)']])

# %%
y_pred[:10]
# Out:
# array([[0.27],
#        [0.74],
#        [0.58],
#        [0.8 ],
#        [0.59],
#        [0.71],
#        [0.65],
#        [0.91],
#        [0.46],
#        [0.72]], dtype=float32)

# %%
np.set_printoptions(precision=2)
compare = np.concatenate((y_pred.reshape(len(y_pred),1), y_test.values.reshape(len(y_test),1)),1)

for i in compare[5000:5050]:
  print(i)
# Out:
# [0.93 0.82]
# [0.52 0.15]
# [0.79 0.82]
# [0.61 0.58]
# [0.98 0.95]
# [0.85 0.78]
# [0.46 0.43]
# [0.62 0.75]
# [1.11 0.47]
# [0.88 0.13]
# [0.59 0.58]
# [0.62 0.83]
# [0.71 0.77]
# [0.13 0.08]
# [0.97 0.77]
# [0.61 0.58]
# [0.56 0.  ]
# [1.07 0.95]
# [0.59 0.67]
# [0.46 0.4 ]
# [0.58 0.3 ]
# [0.59 0.25]
# [0.81 0.77]
# [0.77 0.6 ]
# [0.26 0.22]
# [0.86 0.75]
# [0.54 0.5 ]
# [0.7  0.65]
# [0.72 0.82]
# [0.71 0.88]
# [0.51 0.13]
# [0.09 0.05]
# [0.84 0.87]
# [0.66 0.55]
# [0.25 0.1 ]
# [0.69 0.18]
# [0.69 0.62]
# [0.23 0.23]
# [0.84 0.98]
# [0.27 0.12]
# [0.94 0.85]
# [1.56 0.15]
# [0.58 0.63]
# [0.24 0.42]
# [0.71 0.92]
# [0.4  0.12]
# [0.58 0.57]
# [0.31 0.25]
# [0.85 0.78]
# [0.59 0.52]

# %%
  plt.figure(figsize=(20, 10))

  # Plot test data in green
  plt.scatter(y_test[:5470], y_test[:5470], c="g", label="Testing data")

  # Plot the predictions in red (predictions were made on the test data)
  plt.scatter(y_test[:5470], y_pred[:5470], c="r", s=4, label="Predictions")
  # Show the legend
  plt.legend();

# %%
y_test.shape
# Out:
# (5470,)

# %%
y_pred_heat = np.array(tf.squeeze(y_pred))
y_pred_heat.shape, y_test.shape

y_pred_heat[:10]
y_test[:10]

plt.figure(figsize=(20, 10))
plt.hist2d(y_test[:2000], np.array(tf.squeeze(y_pred))[:2000], bins=40, cmap='jet')
plt.colorbar()
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.show()
